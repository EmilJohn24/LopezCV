# %%
# organize imports
import cv2
import imutils
import numpy as np

# global variables
bg = None

# %%
#--------------------------------------------------
# To find the running average over the background
#--------------------------------------------------
def run_avg(image, aWeight):
    global bg
    # initialize the background
    if bg is None:
        bg = image.copy().astype("float")
        return

    # compute weighted average, accumulate it and update the background
    cv2.accumulateWeighted(image, bg, aWeight)

# %%
#---------------------------------------------
# To segment the region of hand in the image
#---------------------------------------------
def segment(image, threshold=25):
    global bg
    # find the absolute difference between background and current frame
    diff = cv2.absdiff(bg.astype("uint8"), image)

    # threshold the diff image so that we get the foreground
    thresholded = cv2.threshold(diff, threshold, 255, cv2.THRESH_BINARY)[1]

    # get the contours in the thresholded image
    (cnts,_) = cv2.findContours(thresholded.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # return None, if no contours detected
    if len(cnts) == 0:
        return
    else:
        # based on contour area, get the maximum contour which is the hand
        segmented = max(cnts, key=cv2.contourArea)
        return (thresholded, segmented)

# %%
#-----------------
# MAIN FUNCTION
#-----------------
if __name__ == "__main__":
    # initialize weight for running average
    aWeight = 0.5

    # get the reference to the webcam
    camera = cv2.VideoCapture(1)

    # region of interest (ROI) coordinates
    top, right, bottom, left = 10, 350, 225, 590

    # initialize num of frames
    num_frames = 0

    # keep looping, until interrupted
    while(True):
        # get the current frame
        (grabbed, frame) = camera.read()

        # resize the frame
        frame = imutils.resize(frame, width=700)

        # flip the frame so that it is not the mirror view
        frame = cv2.flip(frame, 1)

        # clone the frame
        clone = frame.copy()

        # get the height and width of the frame
        (height, width) = frame.shape[:2]

        # get the ROI
        roi = frame[top:bottom, right:left]

        # convert the roi to grayscale and blur it
        gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
        gray = cv2.GaussianBlur(gray, (7, 7), 0)

        # to get the background, keep looking till a threshold is reached
        # so that our running average model gets calibrated
        if num_frames < 30:
            run_avg(gray, aWeight)
        else:
            # segment the hand region
            hand = segment(gray)

            # check whether hand region is segmented
            if hand is not None:
                # if yes, unpack the thresholded image and
                # segmented region
                (thresholded, segmented) = hand

                # draw the segmented region and display the frame
                cv2.drawContours(clone, [segmented + (right, top)], -1, (0, 0, 255))
                cv2.imshow("Thesholded", thresholded)

        # draw the segmented hand
        cv2.rectangle(clone, (left, top), (right, bottom), (0,255,0), 2)

        # increment the number of frames
        num_frames += 1

        # display the frame with segmented hand
        cv2.imshow("Video Feed", clone)

        # observe the keypress by the user
        keypress = cv2.waitKey(1) & 0xFF

        # if the user pressed "q", then stop looping
        if keypress == ord("q"):
            break

# free up memory
camera.release()
cv2.destroyAllWindows()

# %%
#------------------------------------------------------------
# SEGMENT, RECOGNIZE and COUNT fingers from a video sequence
#------------------------------------------------------------

# organize imports
import cv2
import imutils
import numpy as np
from sklearn.metrics import pairwise

# global variables
bg = None

#--------------------------------------------------
# To find the running average over the background
#--------------------------------------------------
def run_avg(image, accumWeight):
    global bg
    # initialize the background
    if bg is None:
        bg = image.copy().astype("float")
        return

    # compute weighted average, accumulate it and update the background
    cv2.accumulateWeighted(image, bg, accumWeight)

#---------------------------------------------
# To segment the region of hand in the image
#---------------------------------------------
def segment(image, threshold=25):
    global bg
    # find the absolute difference between background and current frame
    diff = cv2.absdiff(bg.astype("uint8"), image)

    # threshold the diff image so that we get the foreground
    thresholded = cv2.threshold(diff, threshold, 255, cv2.THRESH_BINARY)[1]

    # get the contours in the thresholded image
    (cnts, _) = cv2.findContours(thresholded.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # return None, if no contours detected
    if len(cnts) == 0:
        return
    else:
        # based on contour area, get the maximum contour which is the hand
        segmented = max(cnts, key=cv2.contourArea)
        return (thresholded, segmented)

#--------------------------------------------------------------
# To count the number of fingers in the segmented hand region
#--------------------------------------------------------------
def count(thresholded, segmented):
    # find the convex hull of the segmented hand region
    chull = cv2.convexHull(segmented)

    # find the most extreme points in the convex hull
    extreme_top    = tuple(chull[chull[:, :, 1].argmin()][0])
    extreme_bottom = tuple(chull[chull[:, :, 1].argmax()][0])
    extreme_left   = tuple(chull[chull[:, :, 0].argmin()][0])
    extreme_right  = tuple(chull[chull[:, :, 0].argmax()][0])

    # find the center of the palm
    cX = int((extreme_left[0] + extreme_right[0]) / 2)
    cY = int((extreme_top[1] + extreme_bottom[1]) / 2)

    # find the maximum euclidean distance between the center of the palm
    # and the most extreme points of the convex hull
    distance = pairwise.euclidean_distances([(cX, cY)], Y=[extreme_left, extreme_right, extreme_top, extreme_bottom])[0]
    maximum_distance = distance[distance.argmax()]

    # calculate the radius of the circle with 80% of the max euclidean distance obtained
    radius = int(0.8 * maximum_distance)

    # find the circumference of the circle
    circumference = (2 * np.pi * radius)

    # take out the circular region of interest which has 
    # the palm and the fingers
    circular_roi = np.zeros(thresholded.shape[:2], dtype="uint8")
	
    # draw the circular ROI
    cv2.circle(circular_roi, (cX, cY), radius, 255, 1)

    # take bit-wise AND between thresholded hand using the circular ROI as the mask
    # which gives the cuts obtained using mask on the thresholded hand image
    circular_roi = cv2.bitwise_and(thresholded, thresholded, mask=circular_roi)

    # compute the contours in the circular ROI
    (cnts, _) = cv2.findContours(circular_roi.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    # initalize the finger count
    count = 0

    # loop through the contours found
    for c in cnts:
        # compute the bounding box of the contour
        (x, y, w, h) = cv2.boundingRect(c)

        # increment the count of fingers only if -
        # 1. The contour region is not the wrist (bottom area)
        # 2. The number of points along the contour does not exceed
        #     25% of the circumference of the circular ROI
        if ((cY + (cY * 0.25)) > (y + h)) and ((circumference * 0.25) > c.shape[0]):
            count += 1

    return count

#-----------------
# MAIN FUNCTION
#-----------------
if __name__ == "__main__":
    # initialize accumulated weight
    accumWeight = 0.5

    # get the reference to the webcam
    camera = cv2.VideoCapture(1)

    # region of interest (ROI) coordinates
    top, right, bottom, left = 10, 350, 225, 590

    # initialize num of frames
    num_frames = 0

    # calibration indicator
    calibrated = False

    # keep looping, until interrupted
    while(True):
        # get the current frame
        (grabbed, frame) = camera.read()

        # resize the frame
        frame = imutils.resize(frame, width=700)

        # flip the frame so that it is not the mirror view
        frame = cv2.flip(frame, 1)

        # clone the frame
        clone = frame.copy()

        # get the height and width of the frame
        (height, width) = frame.shape[:2]

        # get the ROI
        roi = frame[top:bottom, right:left]

        # convert the roi to grayscale and blur it
        gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
        gray = cv2.GaussianBlur(gray, (7, 7), 0)

        # to get the background, keep looking till a threshold is reached
        # so that our weighted average model gets calibrated
        if num_frames < 30:
            run_avg(gray, accumWeight)
            if num_frames == 1:
                print("[STATUS] please wait! calibrating...")
            elif num_frames == 29:
                print("[STATUS] calibration successfull...")
        else:
            # segment the hand region
            hand = segment(gray)

            # check whether hand region is segmented
            if hand is not None:
                # if yes, unpack the thresholded image and
                # segmented region
                (thresholded, segmented) = hand

                # draw the segmented region and display the frame
                cv2.drawContours(clone, [segmented + (right, top)], -1, (0, 0, 255))

                # count the number of fingers
                fingers = count(thresholded, segmented)

                cv2.putText(clone, str(fingers), (70, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
                
                # show the thresholded image
                cv2.imshow("Thesholded", thresholded)

        # draw the segmented hand
        cv2.rectangle(clone, (left, top), (right, bottom), (0,255,0), 2)

        # increment the number of frames
        num_frames += 1

        # display the frame with segmented hand
        cv2.imshow("Video Feed", clone)

        # observe the keypress by the user
        keypress = cv2.waitKey(1) & 0xFF

        # if the user pressed "q", then stop looping
        if keypress == ord("q"):
            break

# free up memory
camera.release()
cv2.destroyAllWindows()
# Out:
# [STATUS] please wait! calibrating...
# [STATUS] calibration successfull...

# %%
"""
In this section, I will experiment with finger tracking instead
"""
import cv2
import numpy as np

traverse_point = []
total_rectangle = 9
hand_rect_one_x = None
hand_rect_one_y = None

hand_rect_two_x = None
hand_rect_two_y = None


def rescale_frame(frame, wpercent=130, hpercent=130):
    width = int(frame.shape[1] * wpercent / 100)
    height = int(frame.shape[0] * hpercent / 100)
    return cv2.resize(frame, (width, height), interpolation=cv2.INTER_AREA)


def contours(hist_mask_image):
    gray_hist_mask_image = cv2.cvtColor(hist_mask_image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray_hist_mask_image, 0, 255, 0)
    cont, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    return cont


def max_contour(contour_list):
    max_i = 0
    max_area = 0

    for i in range(len(contour_list)):
        cnt = contour_list[i]

        area_cnt = cv2.contourArea(cnt)

        if area_cnt > max_area:
            max_area = area_cnt
            max_i = i

        return contour_list[max_i]


def draw_rect(frame):
    rows, cols, _ = frame.shape
    global total_rectangle, hand_rect_one_x, hand_rect_one_y, hand_rect_two_x, hand_rect_two_y

    hand_rect_one_x = np.array(
        [6 * rows / 20, 6 * rows / 20, 6 * rows / 20, 9 * rows / 20, 9 * rows / 20, 9 * rows / 20, 12 * rows / 20,
         12 * rows / 20, 12 * rows / 20], dtype=np.uint32)

    hand_rect_one_y = np.array(
        [9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20,
         10 * cols / 20, 11 * cols / 20], dtype=np.uint32)

    hand_rect_two_x = hand_rect_one_x + 10
    hand_rect_two_y = hand_rect_one_y + 10

    for i in range(total_rectangle):
        cv2.rectangle(frame, (hand_rect_one_y[i], hand_rect_one_x[i]),
                      (hand_rect_two_y[i], hand_rect_two_x[i]),
                      (0, 255, 0), 1)

    return frame


def hand_histogram(frame):
    global hand_rect_one_x, hand_rect_one_y
    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    roi = np.zeros([90, 10, 3], dtype=hsv_frame.dtype)    
    
    for i in range(total_rectangle):
        roi[i * 10: i * 10 + 10, 0: 10] = hsv_frame[hand_rect_one_x[i]:hand_rect_one_x[i] + 10,
                                          hand_rect_one_y[i]:hand_rect_one_y[i] + 10]

    hand_hist = cv2.calcHist([roi], [0, 1], None, [180, 256], [0, 180, 0, 256])
    return cv2.normalize(hand_hist, hand_hist, 0, 255, cv2.NORM_MINMAX)


def hist_masking(frame, hist):
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    dst = cv2.calcBackProject([hsv], [0, 1], hist, [0, 180, 0, 256], 1)

    disc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (31, 31))
    cv2.filter2D(dst, -1, disc, dst)

    ret, thresh = cv2.threshold(dst, 150, 255, cv2.THRESH_BINARY)

    # thresh = cv2.dilate(thresh, None, iterations=5)

    thresh = cv2.merge((thresh, thresh, thresh))

    return cv2.bitwise_and(frame, thresh)


def centroid(max_contour):
    moment = cv2.moments(max_contour)
    if moment['m00'] != 0:
        cx = int(moment['m10'] / moment['m00'])
        cy = int(moment['m01'] / moment['m00'])
        return cx, cy
    else:
        return None


def farthest_point(defects, contour, centroid):
    if defects is not None and centroid is not None:
        s = defects[:, 0][:, 0]
        cx, cy = centroid

        x = np.array(contour[s][:, 0][:, 0], dtype=np.float)
        y = np.array(contour[s][:, 0][:, 1], dtype=np.float)

        xp = cv2.pow(cv2.subtract(x, cx), 2)
        yp = cv2.pow(cv2.subtract(y, cy), 2)
        dist = cv2.sqrt(cv2.add(xp, yp))

        dist_max_i = np.argmax(dist)

        if dist_max_i < len(s):
            farthest_defect = s[dist_max_i]
            farthest_point = tuple(contour[farthest_defect][0])
            return farthest_point
        else:
            return None


def draw_circles(frame, traverse_point):
    if traverse_point is not None:
        for i in range(len(traverse_point)):
            cv2.circle(frame, traverse_point[i], int(5 - (5 * i * 3) / 100), [0, 255, 255], -1)


def manage_image_opr(frame, hand_hist):
    hist_mask_image = hist_masking(frame, hand_hist)
    contour_list = contours(hist_mask_image)
    max_cont = max_contour(contour_list)

    cnt_centroid = centroid(max_cont)
    cv2.circle(frame, cnt_centroid, 5, [255, 0, 255], -1)

    if max_cont is not None:
        hull = cv2.convexHull(max_cont, returnPoints=False)
        defects = cv2.convexityDefects(max_cont, hull)
        far_point = farthest_point(defects, max_cont, cnt_centroid)
        print("Centroid : " + str(cnt_centroid) + ", farthest Point : " + str(far_point))
        cv2.circle(frame, far_point, 5, [0, 0, 255], -1)
        if len(traverse_point) < 20:
            traverse_point.append(far_point)
        else:
            traverse_point.pop(0)
            traverse_point.append(far_point)

        draw_circles(frame, traverse_point)
#-----------------
# MAIN FUNCTION
#-----------------
if __name__ == "__main__":
    global hand_hist
    is_hand_hist_created = False
    # get the reference to the webcam
    camera = cv2.VideoCapture(0)

    preprocessed = None
    num_frames = 0

    # keep looping, until interrupted
    while(camera.isOpened()):
        pressed_key = cv2.waitKey(1)
        # get the current frame
        (grabbed, preprocessed) = camera.read()

        # flip the frame so that it is not the mirror view
        preprocessed = cv2.flip(preprocessed, 1)
        
        #Copy the frame to display preprocessed and post-processed image
        processed = preprocessed.copy()
        if pressed_key & 0xFF == ord('z'):
            is_hand_hist_created = True
            hand_hist = hand_histogram(processed)

        if is_hand_hist_created:
            manage_image_opr(processed, hand_hist)
        else:
            processed = draw_rect(processed) 




        # increment the number of frames
        num_frames += 1

        # display the frame with segmented hand
        cv2.imshow("Video Feed", preprocessed)
        cv2.imshow("Hand Feed", processed)

        # observe the keypress by the user
        keypress = cv2.waitKey(1) & 0xFF

        # if the user pressed "q", then stop looping
        if keypress == ord("q"):
            break

    # free up memory
    camera.release()
    cv2.destroyAllWindows()
# Out:
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (368, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (567, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (251, 476), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (430, 478), farthest Point : None
# Centroid : (503, 440), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (238, 478), farthest Point : None
# Centroid : (238, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (242, 478), farthest Point : None
# Centroid : (139, 476), farthest Point : (136, 475)
# Centroid : (252, 476), farthest Point : (254, 479)
# Centroid : None, farthest Point : None
# Centroid : (508, 478), farthest Point : None
# Centroid : (261, 474), farthest Point : (267, 469)
# Centroid : (145, 477), farthest Point : None
# Centroid : (145, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (120, 473), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (260, 472), farthest Point : (275, 476)
# Centroid : None, farthest Point : None
# Centroid : (379, 478), farthest Point : (381, 479)
# Centroid : (260, 472), farthest Point : (270, 470)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (561, 434), farthest Point : None
# Centroid : (262, 475), farthest Point : (266, 472)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (252, 477), farthest Point : (255, 476)
# Centroid : (162, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (280, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (127, 476), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (284, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (135, 478), farthest Point : None
# Centroid : (135, 478), farthest Point : None
# Centroid : (252, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (148, 472), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (422, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (130, 477), farthest Point : (133, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (266, 466), farthest Point : (259, 464)
# Centroid : None, farthest Point : None
# Centroid : (276, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (227, 477), farthest Point : (231, 479)
# Centroid : None, farthest Point : None
# Centroid : (267, 474), farthest Point : (279, 477)
# Centroid : None, farthest Point : None
# Centroid : (395, 435), farthest Point : (397, 436)
# Centroid : (364, 478), farthest Point : None
# Centroid : (261, 476), farthest Point : None
# Centroid : (259, 477), farthest Point : None
# Centroid : (142, 474), farthest Point : (127, 479)
# Centroid : (377, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (140, 477), farthest Point : (146, 477)
# Centroid : (142, 476), farthest Point : (150, 476)
# Centroid : (249, 472), farthest Point : (247, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (246, 477), farthest Point : None
# Centroid : (172, 477), farthest Point : None
# Centroid : (511, 476), farthest Point : (514, 479)
# Centroid : (145, 477), farthest Point : (150, 478)
# Centroid : (147, 477), farthest Point : (153, 477)
# Centroid : (134, 478), farthest Point : None
# Centroid : (142, 477), farthest Point : (149, 477)
# Centroid : (277, 459), farthest Point : (275, 456)
# Centroid : None, farthest Point : None
# Centroid : (234, 475), farthest Point : (230, 476)
# Centroid : (122, 478), farthest Point : None
# Centroid : (392, 467), farthest Point : None
# Centroid : (281, 478), farthest Point : None
# Centroid : (258, 472), farthest Point : (272, 471)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (266, 473), farthest Point : (281, 475)
# Centroid : (518, 467), farthest Point : (520, 466)
# Centroid : None, farthest Point : None
# Centroid : (151, 461), farthest Point : None
# Centroid : (266, 473), farthest Point : (277, 468)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (138, 477), farthest Point : None
# Centroid : (253, 477), farthest Point : (255, 478)
# Centroid : (264, 475), farthest Point : (261, 471)
# Centroid : None, farthest Point : None
# Centroid : (271, 475), farthest Point : (276, 471)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (265, 473), farthest Point : (279, 477)
# Centroid : (375, 478), farthest Point : None
# Centroid : (265, 474), farthest Point : (275, 472)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (239, 476), farthest Point : (240, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (392, 473), farthest Point : (396, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (411, 471), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (252, 464), farthest Point : (254, 463)
# Centroid : None, farthest Point : None
# Centroid : (514, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (495, 478), farthest Point : None
# Centroid : (144, 477), farthest Point : (137, 479)
# Centroid : (385, 454), farthest Point : None
# Centroid : (385, 454), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (265, 473), farthest Point : (250, 477)
# Centroid : (424, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (261, 474), farthest Point : (273, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (379, 477), farthest Point : (383, 478)
# Centroid : None, farthest Point : None
# Centroid : (574, 476), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (505, 477), farthest Point : (511, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (188, 469), farthest Point : (191, 468)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (428, 477), farthest Point : (430, 475)
# Centroid : (206, 469), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (217, 478), farthest Point : (221, 479)
# Centroid : None, farthest Point : None
# Centroid : (444, 406), farthest Point : None
# Centroid : (444, 406), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (319, 236), farthest Point : (0, 479)
# Centroid : (549, 472), farthest Point : None
# Centroid : (232, 431), farthest Point : (235, 430)
# Centroid : None, farthest Point : None
# Centroid : (467, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (627, 432), farthest Point : (626, 439)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (469, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (296, 435), farthest Point : (300, 435)
# Centroid : (550, 477), farthest Point : (551, 478)
# Centroid : None, farthest Point : None
# Centroid : (624, 468), farthest Point : (637, 479)
# Centroid : (321, 473), farthest Point : (335, 465)
# Centroid : None, farthest Point : None
# Centroid : (348, 473), farthest Point : (350, 465)
# Centroid : (415, 478), farthest Point : None
# Centroid : (512, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (393, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (618, 466), farthest Point : (620, 467)
# Centroid : (155, 477), farthest Point : None
# Centroid : (619, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (564, 478), farthest Point : (567, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (384, 476), farthest Point : (386, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (338, 478), farthest Point : (342, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (379, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (446, 476), farthest Point : (445, 474)
# Centroid : (601, 473), farthest Point : (598, 474)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (315, 475), farthest Point : (322, 474)
# Centroid : (312, 476), farthest Point : (305, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (488, 473), farthest Point : (501, 476)
# Centroid : None, farthest Point : None
# Centroid : (352, 469), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (357, 474), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (454, 468), farthest Point : (456, 466)
# Centroid : (570, 471), farthest Point : (572, 472)
# Centroid : (329, 240), farthest Point : (639, 0)
# Centroid : (329, 240), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (521, 463), farthest Point : None
# Centroid : (636, 473), farthest Point : (636, 475)
# Centroid : (459, 74), farthest Point : (459, 76)
# Centroid : None, farthest Point : None
# Centroid : (58, 304), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (638, 146), farthest Point : None
# Centroid : (58, 281), farthest Point : (60, 292)
# Centroid : (58, 281), farthest Point : (60, 292)
# Centroid : (616, 301), farthest Point : None
# Centroid : (567, 307), farthest Point : (564, 309)
# Centroid : (636, 321), farthest Point : (634, 325)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (541, 328), farthest Point : None
# Centroid : (519, 316), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (632, 318), farthest Point : (628, 348)
# Centroid : None, farthest Point : None
# Centroid : (56, 316), farthest Point : (59, 315)
# Centroid : (69, 297), farthest Point : (74, 294)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (605, 352), farthest Point : None
# Centroid : (71, 326), farthest Point : (56, 316)
# Centroid : (631, 317), farthest Point : (639, 293)
# Centroid : (631, 317), farthest Point : (639, 293)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (635, 330), farthest Point : (636, 323)
# Centroid : (637, 351), farthest Point : (635, 354)
# Centroid : (637, 337), farthest Point : (638, 335)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (72, 320), farthest Point : (73, 323)
# Centroid : (630, 355), farthest Point : (639, 345)
# Centroid : (636, 350), farthest Point : (635, 344)
# Centroid : (638, 360), farthest Point : None
# Centroid : (531, 359), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (88, 380), farthest Point : None
# Centroid : (355, 367), farthest Point : (355, 351)
# Centroid : (401, 321), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (326, 478), farthest Point : (331, 477)
# Centroid : (127, 467), farthest Point : (136, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (481, 478), farthest Point : None
# Centroid : (438, 466), farthest Point : (454, 476)
# Centroid : (432, 476), farthest Point : (418, 479)
# Centroid : (439, 477), farthest Point : None
# Centroid : (140, 466), farthest Point : (163, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (376, 467), farthest Point : (378, 468)
# Centroid : (436, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (52, 475), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (18, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (83, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (129, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (384, 477), farthest Point : None
# Centroid : (387, 477), farthest Point : (389, 477)
# Centroid : None, farthest Point : None
# Centroid : (166, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (420, 416), farthest Point : None
# Centroid : (567, 460), farthest Point : (588, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (0, 464), farthest Point : (0, 469)
# Centroid : None, farthest Point : None
# Centroid : (551, 461), farthest Point : (566, 470)
# Centroid : (479, 456), farthest Point : (480, 464)
# Centroid : (479, 456), farthest Point : (480, 464)
# Centroid : None, farthest Point : None
# Centroid : (607, 462), farthest Point : (638, 456)
# Centroid : (480, 444), farthest Point : None
# Centroid : (2, 476), farthest Point : None
# Centroid : (5, 474), farthest Point : (15, 477)
# Centroid : (122, 459), farthest Point : (129, 457)
# Centroid : (493, 459), farthest Point : (478, 449)
# Centroid : (482, 439), farthest Point : (470, 456)
# Centroid : (508, 402), farthest Point : (518, 367)
# Centroid : (508, 402), farthest Point : (518, 367)
# Centroid : (526, 443), farthest Point : (478, 431)
# Centroid : None, farthest Point : None
# Centroid : (477, 464), farthest Point : (495, 455)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (341, 441), farthest Point : (345, 444)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (429, 462), farthest Point : None
# Centroid : (429, 462), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (628, 463), farthest Point : (638, 448)
# Centroid : (472, 459), farthest Point : (488, 456)
# Centroid : (631, 468), farthest Point : (638, 455)
# Centroid : (576, 453), farthest Point : (598, 471)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (500, 441), farthest Point : (516, 438)
# Centroid : (500, 441), farthest Point : (516, 438)
# Centroid : (630, 446), farthest Point : (639, 432)
# Centroid : (588, 464), farthest Point : (602, 473)
# Centroid : (624, 469), farthest Point : (609, 476)
# Centroid : (632, 472), farthest Point : (633, 465)
# Centroid : (592, 459), farthest Point : (608, 456)
# Centroid : (574, 461), farthest Point : (594, 474)
# Centroid : (518, 404), farthest Point : (534, 401)
# Centroid : (572, 457), farthest Point : (594, 474)
# Centroid : (568, 464), farthest Point : (582, 473)
# Centroid : (497, 446), farthest Point : (502, 442)
# Centroid : (575, 461), farthest Point : (603, 471)
# Centroid : (637, 478), farthest Point : (634, 477)
# Centroid : (567, 458), farthest Point : (575, 479)
# Centroid : (632, 471), farthest Point : (633, 462)
# Centroid : (564, 461), farthest Point : (580, 458)
# Centroid : (622, 458), farthest Point : (638, 455)
# Centroid : (569, 464), farthest Point : (584, 461)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (624, 469), farthest Point : (609, 476)
# Centroid : (566, 450), farthest Point : (582, 447)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (551, 285), farthest Point : None
# Centroid : (532, 421), farthest Point : (547, 418)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (3, 476), farthest Point : (10, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (588, 466), farthest Point : (601, 475)
# Centroid : (618, 364), farthest Point : (634, 361)
# Centroid : (429, 472), farthest Point : (431, 475)
# Centroid : (570, 464), farthest Point : (561, 477)
# Centroid : (496, 447), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (518, 364), farthest Point : (534, 361)
# Centroid : None, farthest Point : None
# Centroid : (631, 469), farthest Point : (639, 457)
# Centroid : (469, 478), farthest Point : (473, 479)
# Centroid : None, farthest Point : None
# Centroid : (631, 461), farthest Point : (638, 442)
# Centroid : (631, 466), farthest Point : (634, 453)
# Centroid : (562, 456), farthest Point : (578, 453)
# Centroid : (629, 451), farthest Point : (638, 418)
# Centroid : (617, 460), farthest Point : (639, 448)
# Centroid : None, farthest Point : None
# Centroid : (614, 444), farthest Point : (632, 441)
# Centroid : (620, 443), farthest Point : (623, 448)
# Centroid : (625, 431), farthest Point : (627, 449)
# Centroid : (605, 453), farthest Point : (575, 461)
# Centroid : (620, 453), farthest Point : (602, 428)
# Centroid : (615, 264), farthest Point : (632, 268)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (484, 478), farthest Point : None
# Centroid : (492, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (635, 458), farthest Point : (631, 457)
# Centroid : (630, 449), farthest Point : (629, 451)
# Centroid : (622, 459), farthest Point : (625, 461)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (399, 477), farthest Point : (402, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (226, 478), farthest Point : (228, 477)
# Centroid : (226, 478), farthest Point : (228, 477)
# Centroid : (468, 466), farthest Point : (445, 476)
# Centroid : (226, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (258, 470), farthest Point : None
# Centroid : (266, 476), farthest Point : (275, 479)
# Centroid : None, farthest Point : None
# Centroid : (258, 477), farthest Point : (263, 479)
# Centroid : (258, 477), farthest Point : (263, 479)
# Centroid : (256, 476), farthest Point : (263, 479)
# Centroid : (257, 477), farthest Point : (263, 479)
# Centroid : None, farthest Point : None
# Centroid : (258, 476), farthest Point : (261, 473)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (421, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (465, 455), farthest Point : (443, 476)
# Centroid : None, farthest Point : None
# Centroid : (453, 403), farthest Point : None
# Centroid : (537, 472), farthest Point : (555, 476)
# Centroid : (580, 467), farthest Point : (593, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (546, 472), farthest Point : (529, 479)
# Centroid : (547, 472), farthest Point : (532, 479)
# Centroid : (543, 472), farthest Point : (559, 476)
# Centroid : (486, 416), farthest Point : (503, 417)
# Centroid : None, farthest Point : None
# Centroid : (547, 472), farthest Point : (563, 476)
# Centroid : (539, 306), farthest Point : None
# Centroid : (511, 423), farthest Point : (513, 426)
# Centroid : (147, 460), farthest Point : None
# Centroid : (512, 425), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (614, 437), farthest Point : (629, 434)
# Centroid : (593, 468), farthest Point : (607, 479)
# Centroid : (501, 409), farthest Point : (504, 410)
# Centroid : (581, 359), farthest Point : (582, 364)
# Centroid : (561, 472), farthest Point : (582, 476)
# Centroid : None, farthest Point : None
# Centroid : (590, 464), farthest Point : (543, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (571, 471), farthest Point : (594, 476)
# Centroid : (577, 471), farthest Point : (608, 474)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (93, 476), farthest Point : (100, 479)
# Centroid : (570, 471), farthest Point : (596, 475)
# Centroid : (544, 408), farthest Point : None
# Centroid : (76, 477), farthest Point : (86, 478)
# Centroid : (571, 471), farthest Point : (598, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (97, 475), farthest Point : (105, 473)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (553, 410), farthest Point : (552, 413)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (571, 390), farthest Point : None
# Centroid : (238, 467), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (511, 418), farthest Point : None
# Centroid : (532, 415), farthest Point : (531, 410)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (295, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (373, 465), farthest Point : None
# Centroid : (446, 467), farthest Point : (445, 470)
# Centroid : (353, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (545, 93), farthest Point : None
# Centroid : (630, 468), farthest Point : (639, 457)
# Centroid : (559, 66), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (559, 91), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (638, 51), farthest Point : None
# Centroid : (601, 418), farthest Point : (599, 418)
# Centroid : None, farthest Point : None
# Centroid : (586, 423), farthest Point : (580, 425)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (608, 478), farthest Point : (609, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (638, 435), farthest Point : None
# Centroid : (630, 75), farthest Point : (632, 77)
# Centroid : None, farthest Point : None
# Centroid : (48, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (624, 471), farthest Point : (610, 471)
# Centroid : (614, 471), farthest Point : (631, 474)
# Centroid : (596, 470), farthest Point : (621, 472)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (567, 462), farthest Point : (594, 475)
# Centroid : (530, 443), farthest Point : None
# Centroid : (583, 462), farthest Point : (615, 457)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (580, 466), farthest Point : (537, 479)
# Centroid : (564, 470), farthest Point : (581, 475)
# Centroid : (515, 473), farthest Point : (501, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (500, 460), farthest Point : (499, 462)
# Centroid : (536, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (515, 462), farthest Point : (505, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (309, 478), farthest Point : (321, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (570, 469), farthest Point : (585, 479)
# Centroid : (531, 476), farthest Point : (537, 479)
# Centroid : (579, 468), farthest Point : (592, 478)
# Centroid : (567, 467), farthest Point : (537, 472)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (612, 383), farthest Point : (628, 380)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (549, 476), farthest Point : None
# Centroid : (589, 472), farthest Point : (606, 476)
# Centroid : (596, 472), farthest Point : (581, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (590, 468), farthest Point : (604, 478)
# Centroid : (561, 8), farthest Point : (567, 25)
# Centroid : (310, 235), farthest Point : (639, 0)
# Centroid : (622, 339), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (548, 453), farthest Point : (549, 457)
# Centroid : (638, 347), farthest Point : None
# Centroid : (310, 236), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (576, 76), farthest Point : (573, 76)
# Centroid : None, farthest Point : None
# Centroid : (310, 235), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (606, 71), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (310, 237), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (604, 449), farthest Point : (620, 446)
# Centroid : (638, 358), farthest Point : (639, 356)
# Centroid : None, farthest Point : None
# Centroid : (552, 442), farthest Point : (550, 444)
# Centroid : None, farthest Point : None
# Centroid : (533, 441), farthest Point : None
# Centroid : (591, 71), farthest Point : (590, 70)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (598, 472), farthest Point : (614, 476)
# Centroid : (579, 11), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (558, 443), farthest Point : (557, 448)
# Centroid : (616, 451), farthest Point : (631, 448)
# Centroid : None, farthest Point : None
# Centroid : (548, 443), farthest Point : None
# Centroid : (638, 30), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (631, 18), farthest Point : (634, 43)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (534, 472), farthest Point : (519, 479)
# Centroid : (496, 440), farthest Point : (500, 440)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (503, 470), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (206, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (187, 478), farthest Point : None
# Centroid : (187, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (223, 474), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (494, 477), farthest Point : (495, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (492, 478), farthest Point : (495, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (465, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (638, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (441, 467), farthest Point : (456, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (272, 477), farthest Point : (275, 476)
# Centroid : (86, 472), farthest Point : (71, 479)
# Centroid : None, farthest Point : None
# Centroid : (56, 466), farthest Point : (117, 479)
# Centroid : (58, 463), farthest Point : (123, 476)
# Centroid : (276, 478), farthest Point : None
# Centroid : (576, 460), farthest Point : (592, 457)
# Centroid : (612, 445), farthest Point : (628, 442)
# Centroid : (73, 450), farthest Point : (164, 451)
# Centroid : (600, 435), farthest Point : (610, 438)
# Centroid : (612, 441), farthest Point : (628, 438)
# Centroid : (536, 478), farthest Point : None
# Centroid : (636, 381), farthest Point : (634, 388)
# Centroid : (632, 462), farthest Point : (638, 447)
# Centroid : (97, 418), farthest Point : (259, 452)
# Centroid : (630, 210), farthest Point : (631, 218)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (475, 398), farthest Point : (467, 396)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (455, 362), farthest Point : None
# Centroid : (489, 350), farthest Point : (492, 350)
# Centroid : None, farthest Point : None
# Centroid : (543, 421), farthest Point : (545, 423)
# Centroid : None, farthest Point : None
# Centroid : (488, 350), farthest Point : None
# Centroid : (568, 431), farthest Point : (565, 428)
# Centroid : None, farthest Point : None
# Centroid : (627, 462), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (524, 439), farthest Point : None
# Centroid : (537, 420), farthest Point : None
# Centroid : (638, 392), farthest Point : (639, 391)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (352, 450), farthest Point : None
# Centroid : (331, 452), farthest Point : (336, 453)
# Centroid : (564, 470), farthest Point : (615, 478)
# Centroid : (637, 182), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (317, 240), farthest Point : (639, 479)
# Centroid : (318, 239), farthest Point : None
# Centroid : (319, 239), farthest Point : None
# Centroid : (319, 239), farthest Point : None
# Centroid : (319, 239), farthest Point : None
# Centroid : (319, 239), farthest Point : (639, 0)
# Centroid : (537, 473), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (549, 429), farthest Point : (547, 432)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (614, 472), farthest Point : (630, 476)
# Centroid : (629, 446), farthest Point : None
# Centroid : (493, 471), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (484, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (622, 473), farthest Point : None
# Centroid : (369, 347), farthest Point : (368, 355)
# Centroid : (372, 477), farthest Point : (376, 479)
# Centroid : (517, 478), farthest Point : (520, 478)
# Centroid : (14, 448), farthest Point : (12, 452)
# Centroid : (19, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (491, 475), farthest Point : None
# Centroid : (477, 396), farthest Point : None
# Centroid : (477, 396), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (505, 474), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (359, 478), farthest Point : None
# Centroid : (50, 478), farthest Point : (53, 479)
# Centroid : None, farthest Point : None
# Centroid : (435, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (602, 478), farthest Point : (607, 477)
# Centroid : (602, 478), farthest Point : (607, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (636, 478), farthest Point : (639, 478)
# Centroid : None, farthest Point : None
# Centroid : (536, 461), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (387, 419), farthest Point : (413, 404)
# Centroid : (387, 419), farthest Point : (413, 404)
# Centroid : None, farthest Point : None
# Centroid : (368, 112), farthest Point : (372, 113)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (318, 239), farthest Point : None
# Centroid : (316, 241), farthest Point : (639, 479)
# Centroid : (316, 241), farthest Point : (639, 2)
# Centroid : (316, 241), farthest Point : (639, 2)
# Centroid : (316, 241), farthest Point : (639, 2)
# Centroid : (316, 241), farthest Point : (639, 0)
# Centroid : (316, 241), farthest Point : (639, 0)
# Centroid : (317, 241), farthest Point : (639, 0)
# Centroid : (317, 241), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (317, 240), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (317, 240), farthest Point : (639, 0)
# Centroid : (317, 240), farthest Point : (639, 479)
# Centroid : (317, 240), farthest Point : (639, 479)
# Centroid : (627, 11), farthest Point : (627, 25)
# Centroid : None, farthest Point : None
# Centroid : (632, 19), farthest Point : (627, 29)
# Centroid : None, farthest Point : None
# Centroid : (318, 240), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (267, 475), farthest Point : (272, 474)
# Centroid : (255, 470), farthest Point : (277, 479)
# Centroid : (434, 469), farthest Point : (449, 479)
# Centroid : (351, 472), farthest Point : (396, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (404, 452), farthest Point : (408, 456)
# Centroid : None, farthest Point : None
# Centroid : (357, 468), farthest Point : (356, 467)
# Centroid : (167, 478), farthest Point : None
# Centroid : (271, 477), farthest Point : (278, 476)
# Centroid : (190, 477), farthest Point : (197, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (479, 471), farthest Point : (496, 474)
# Centroid : (484, 449), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (422, 449), farthest Point : (423, 449)
# Centroid : None, farthest Point : None
# Centroid : (50, 475), farthest Point : (53, 473)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (355, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (568, 36), farthest Point : (570, 49)
# Centroid : None, farthest Point : None
# Centroid : (541, 475), farthest Point : (546, 477)
# Centroid : (25, 423), farthest Point : (0, 479)
# Centroid : (1, 478), farthest Point : None
# Centroid : (259, 472), farthest Point : (261, 470)
# Centroid : (21, 432), farthest Point : (15, 479)
# Centroid : (238, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (294, 478), farthest Point : (307, 479)
# Centroid : None, farthest Point : None
# Centroid : (296, 478), farthest Point : (318, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (466, 456), farthest Point : (469, 458)
# Centroid : (231, 434), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (1, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (22, 423), farthest Point : (8, 479)
# Centroid : (5, 474), farthest Point : (12, 473)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (526, 478), farthest Point : (530, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (500, 477), farthest Point : (503, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (3, 477), farthest Point : (9, 477)
# Centroid : (3, 477), farthest Point : (9, 477)
# Centroid : None, farthest Point : None
# Centroid : (473, 478), farthest Point : None
# Centroid : (470, 474), farthest Point : (470, 475)
# Centroid : (457, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (617, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (624, 476), farthest Point : None
# Centroid : (625, 477), farthest Point : None
# Centroid : (625, 476), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (571, 477), farthest Point : (574, 474)
# Centroid : (435, 471), farthest Point : (450, 479)
# Centroid : (521, 474), farthest Point : (542, 471)
# Centroid : None, farthest Point : None
# ...
# Centroid : None, farthest Point : None
# Centroid : (337, 400), farthest Point : (340, 409)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (152, 305), farthest Point : (145, 313)
# Centroid : (473, 222), farthest Point : (475, 224)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (104, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (49, 223), farthest Point : (43, 228)
# Centroid : (637, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (113, 478), farthest Point : None
# Centroid : (0, 192), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (55, 160), farthest Point : (56, 164)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (303, 100), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (333, 109), farthest Point : (335, 115)
# Centroid : None, farthest Point : None
# Centroid : (302, 115), farthest Point : (301, 116)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (2, 151), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (352, 94), farthest Point : (359, 96)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (367, 107), farthest Point : None
# Centroid : (327, 94), farthest Point : (340, 82)
# Centroid : None, farthest Point : None
# Centroid : (336, 97), farthest Point : (339, 97)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (16, 90), farthest Point : None
# Centroid : (47, 76), farthest Point : (52, 77)
# Centroid : None, farthest Point : None
# Centroid : (42, 85), farthest Point : None
# Centroid : (615, 440), farthest Point : (610, 436)
# Centroid : (631, 376), farthest Point : (633, 379)
# Centroid : None, farthest Point : None
# Centroid : (458, 465), farthest Point : (481, 463)
# Centroid : (181, 72), farthest Point : None
# Centroid : (459, 449), farthest Point : (460, 457)
# Centroid : (414, 478), farthest Point : None
# Centroid : (389, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (80, 137), farthest Point : (82, 138)
# Centroid : None, farthest Point : None
# Centroid : (400, 468), farthest Point : (408, 462)
# Centroid : (396, 404), farthest Point : None
# Centroid : (106, 31), farthest Point : (109, 31)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (442, 477), farthest Point : None
# Centroid : (408, 477), farthest Point : (414, 478)
# Centroid : (68, 117), farthest Point : (71, 121)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (141, 63), farthest Point : (151, 74)
# Centroid : (181, 135), farthest Point : (185, 135)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (386, 478), farthest Point : None
# Centroid : (292, 93), farthest Point : (295, 94)
# Centroid : (285, 99), farthest Point : None
# Centroid : (417, 420), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (176, 98), farthest Point : (174, 103)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (3, 75), farthest Point : (0, 81)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (345, 476), farthest Point : (353, 479)
# Centroid : None, farthest Point : None
# Centroid : (30, 61), farthest Point : (1, 84)
# Centroid : (102, 101), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (0, 478), farthest Point : None
# Centroid : (0, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (122, 114), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (49, 74), farthest Point : None
# Centroid : (349, 476), farthest Point : (343, 479)
# Centroid : (349, 476), farthest Point : (343, 479)
# Centroid : (0, 398), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (0, 400), farthest Point : None
# Centroid : (106, 92), farthest Point : (108, 93)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (366, 426), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (0, 346), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (123, 73), farthest Point : (120, 80)
# Centroid : None, farthest Point : None
# Centroid : (1, 338), farthest Point : None
# Centroid : (1, 338), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (120, 66), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (1, 389), farthest Point : (0, 394)
# Centroid : (130, 92), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (121, 73), farthest Point : (131, 76)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (130, 96), farthest Point : (132, 97)
# Centroid : None, farthest Point : None
# Centroid : (1, 444), farthest Point : (0, 448)
# Centroid : (142, 98), farthest Point : None
# Centroid : (123, 80), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (411, 465), farthest Point : (409, 471)
# Centroid : None, farthest Point : None
# Centroid : (146, 64), farthest Point : (149, 64)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (434, 417), farthest Point : (438, 422)
# Centroid : None, farthest Point : None
# Centroid : (145, 34), farthest Point : (146, 36)
# Centroid : (134, 48), farthest Point : (134, 51)
# Centroid : None, farthest Point : None
# Centroid : (158, 8), farthest Point : (168, 23)
# Centroid : (486, 464), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (119, 37), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (314, 244), farthest Point : (639, 7)
# Centroid : None, farthest Point : None
# Centroid : (62, 0), farthest Point : None
# Centroid : (315, 242), farthest Point : (639, 0)
# Centroid : (484, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (315, 242), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (316, 243), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (314, 241), farthest Point : (639, 0)
# Centroid : (315, 242), farthest Point : (639, 0)
# Centroid : (315, 241), farthest Point : (639, 1)
# Centroid : (315, 241), farthest Point : (639, 1)
# Centroid : None, farthest Point : None
# Centroid : (315, 240), farthest Point : (638, 0)
# Centroid : (316, 241), farthest Point : (639, 1)
# Centroid : (316, 241), farthest Point : (639, 1)
# Centroid : (316, 241), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (316, 241), farthest Point : (639, 0)
# Centroid : (317, 241), farthest Point : (639, 0)
# Centroid : (317, 241), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (317, 241), farthest Point : (639, 0)
# Centroid : (317, 241), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (316, 241), farthest Point : (639, 0)
# Centroid : (316, 241), farthest Point : (639, 0)
# Centroid : (316, 241), farthest Point : (639, 0)
# Centroid : (316, 241), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : (317, 241), farthest Point : (639, 0)
# Centroid : (581, 7), farthest Point : (591, 4)
# Centroid : (577, 21), farthest Point : None
# Centroid : (578, 6), farthest Point : (575, 19)
# Centroid : (586, 24), farthest Point : None
# Centroid : (317, 240), farthest Point : (639, 0)
# Centroid : (318, 240), farthest Point : (639, 0)
# Centroid : (587, 1), farthest Point : (586, 4)
# Centroid : None, farthest Point : None
# Centroid : (319, 239), farthest Point : (639, 0)
# Centroid : (318, 240), farthest Point : (639, 0)
# Centroid : (319, 239), farthest Point : (639, 479)
# Centroid : (319, 239), farthest Point : (639, 0)
# Centroid : (319, 239), farthest Point : (638, 0)
# Centroid : None, farthest Point : None
# Centroid : (319, 239), farthest Point : (639, 0)
# Centroid : (319, 239), farthest Point : (639, 0)
# Centroid : (319, 238), farthest Point : (639, 0)
# Centroid : (321, 235), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (53, 475), farthest Point : (55, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (327, 233), farthest Point : (31, 479)
# Centroid : (321, 237), farthest Point : (0, 0)
# Centroid : (628, 449), farthest Point : (639, 434)
# Centroid : (304, 233), farthest Point : (639, 0)
# Centroid : (304, 233), farthest Point : (639, 0)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (3, 475), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (598, 469), farthest Point : (613, 479)
# Centroid : None, farthest Point : None
# Centroid : (596, 425), farthest Point : (553, 471)
# Centroid : (596, 425), farthest Point : (553, 471)
# Centroid : None, farthest Point : None
# Centroid : (584, 423), farthest Point : (505, 433)
# Centroid : (560, 432), farthest Point : (468, 409)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (368, 473), farthest Point : (376, 479)
# Centroid : (492, 478), farthest Point : (497, 478)
# Centroid : (350, 467), farthest Point : (371, 475)
# Centroid : (350, 467), farthest Point : (371, 475)
# Centroid : (358, 473), farthest Point : (371, 477)
# Centroid : (454, 470), farthest Point : (469, 479)
# Centroid : (376, 473), farthest Point : (363, 473)
# Centroid : (368, 465), farthest Point : (348, 451)
# Centroid : (468, 475), farthest Point : (471, 479)
# Centroid : (480, 472), farthest Point : (498, 474)
# Centroid : (487, 475), farthest Point : (499, 477)
# Centroid : None, farthest Point : None
# Centroid : (396, 470), farthest Point : (410, 476)
# Centroid : (396, 470), farthest Point : (410, 476)
# Centroid : (495, 463), farthest Point : (452, 472)
# Centroid : (444, 467), farthest Point : (457, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (409, 478), farthest Point : (411, 479)
# Centroid : (519, 477), farthest Point : None
# Centroid : (426, 456), farthest Point : (442, 453)
# Centroid : (437, 469), farthest Point : (452, 479)
# Centroid : (445, 452), farthest Point : None
# Centroid : (445, 452), farthest Point : None
# Centroid : (547, 475), farthest Point : (561, 477)
# Centroid : None, farthest Point : None
# Centroid : (441, 471), farthest Point : (452, 458)
# Centroid : None, farthest Point : None
# Centroid : (631, 472), farthest Point : (627, 469)
# Centroid : (519, 478), farthest Point : None
# Centroid : (456, 478), farthest Point : (458, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (452, 478), farthest Point : (454, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (372, 477), farthest Point : None
# Centroid : (347, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (573, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (612, 477), farthest Point : (614, 479)
# Centroid : (431, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (361, 476), farthest Point : None
# Centroid : (581, 477), farthest Point : (585, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (585, 473), farthest Point : (589, 474)
# Centroid : None, farthest Point : None
# Centroid : (572, 478), farthest Point : None
# Centroid : (361, 478), farthest Point : (363, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (600, 475), farthest Point : (601, 477)
# Centroid : (400, 477), farthest Point : (404, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (484, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (491, 476), farthest Point : (480, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (313, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (582, 478), farthest Point : None
# Centroid : (607, 472), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (304, 476), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (339, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (613, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (457, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (84, 478), farthest Point : None
# Centroid : (429, 477), farthest Point : (432, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (349, 478), farthest Point : None
# Centroid : (501, 474), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (533, 478), farthest Point : None
# Centroid : (496, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (571, 478), farthest Point : None
# Centroid : (457, 478), farthest Point : (459, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None

# %%
import cv2
import numpy as np

hand_hist = None
traverse_point = []
total_rectangle = 9
hand_rect_one_x = None
hand_rect_one_y = None

hand_rect_two_x = None
hand_rect_two_y = None


def rescale_frame(frame, wpercent=130, hpercent=130):
    width = int(frame.shape[1] * wpercent / 100)
    height = int(frame.shape[0] * hpercent / 100)
    return cv2.resize(frame, (width, height), interpolation=cv2.INTER_AREA)


def contours(hist_mask_image):
    gray_hist_mask_image = cv2.cvtColor(hist_mask_image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray_hist_mask_image, 0, 255, 0)
    cont, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    return cont


def max_contour(contour_list):
    max_i = 0
    max_area = 0

    for i in range(len(contour_list)):
        cnt = contour_list[i]

        area_cnt = cv2.contourArea(cnt)

        if area_cnt > max_area:
            max_area = area_cnt
            max_i = i

        return contour_list[max_i]


def draw_rect(frame):
    rows, cols, _ = frame.shape
    global total_rectangle, hand_rect_one_x, hand_rect_one_y, hand_rect_two_x, hand_rect_two_y

    hand_rect_one_x = np.array(
        [6 * rows / 20, 6 * rows / 20, 6 * rows / 20, 9 * rows / 20, 9 * rows / 20, 9 * rows / 20, 12 * rows / 20,
         12 * rows / 20, 12 * rows / 20], dtype=np.uint32)

    hand_rect_one_y = np.array(
        [9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20,
         10 * cols / 20, 11 * cols / 20], dtype=np.uint32)

    hand_rect_two_x = hand_rect_one_x + 10
    hand_rect_two_y = hand_rect_one_y + 10

    for i in range(total_rectangle):
        cv2.rectangle(frame, (hand_rect_one_y[i], hand_rect_one_x[i]),
                      (hand_rect_two_y[i], hand_rect_two_x[i]),
                      (0, 255, 0), 1)

    return frame


def hand_histogram(frame):
    global hand_rect_one_x, hand_rect_one_y

    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    roi = np.zeros([90, 10, 3], dtype=hsv_frame.dtype)

    for i in range(total_rectangle):
        roi[i * 10: i * 10 + 10, 0: 10] = hsv_frame[hand_rect_one_x[i]:hand_rect_one_x[i] + 10,
                                          hand_rect_one_y[i]:hand_rect_one_y[i] + 10]

    hand_hist = cv2.calcHist([roi], [0, 1], None, [180, 256], [0, 180, 0, 256])
    return cv2.normalize(hand_hist, hand_hist, 0, 255, cv2.NORM_MINMAX)


def hist_masking(frame, hist):
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    dst = cv2.calcBackProject([hsv], [0, 1], hist, [0, 180, 0, 256], 1)

    disc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (31, 31))
    cv2.filter2D(dst, -1, disc, dst)

    ret, thresh = cv2.threshold(dst, 150, 255, cv2.THRESH_BINARY)

    # thresh = cv2.dilate(thresh, None, iterations=5)

    thresh = cv2.merge((thresh, thresh, thresh))

    return cv2.bitwise_and(frame, thresh)


def centroid(max_contour):
    moment = cv2.moments(max_contour)
    if moment['m00'] != 0:
        cx = int(moment['m10'] / moment['m00'])
        cy = int(moment['m01'] / moment['m00'])
        return cx, cy
    else:
        return None


def farthest_point(defects, contour, centroid):
    if defects is not None and centroid is not None:
        s = defects[:, 0][:, 0]
        cx, cy = centroid

        x = np.array(contour[s][:, 0][:, 0], dtype=np.float)
        y = np.array(contour[s][:, 0][:, 1], dtype=np.float)

        xp = cv2.pow(cv2.subtract(x, cx), 2)
        yp = cv2.pow(cv2.subtract(y, cy), 2)
        dist = cv2.sqrt(cv2.add(xp, yp))

        dist_max_i = np.argmax(dist)

        if dist_max_i < len(s):
            farthest_defect = s[dist_max_i]
            farthest_point = tuple(contour[farthest_defect][0])
            return farthest_point
        else:
            return None


def draw_circles(frame, traverse_point):
    if traverse_point is not None:
        for i in range(len(traverse_point)):
            cv2.circle(frame, traverse_point[i], int(5 - (5 * i * 3) / 100), [0, 255, 255], -1)


def manage_image_opr(frame, hand_hist):
    hist_mask_image = hist_masking(frame, hand_hist)
    contour_list = contours(hist_mask_image)
    max_cont = max_contour(contour_list)

    cnt_centroid = centroid(max_cont)
    cv2.circle(frame, cnt_centroid, 5, [255, 0, 255], -1)

    if max_cont is not None:
        hull = cv2.convexHull(max_cont, returnPoints=False)
        defects = cv2.convexityDefects(max_cont, hull)
        far_point = farthest_point(defects, max_cont, cnt_centroid)
        print("Centroid : " + str(cnt_centroid) + ", farthest Point : " + str(far_point))
        cv2.circle(frame, far_point, 5, [0, 0, 255], -1)
        if len(traverse_point) < 20:
            traverse_point.append(far_point)
        else:
            traverse_point.pop(0)
            traverse_point.append(far_point)

        draw_circles(frame, traverse_point)


def main():
    global hand_hist
    is_hand_hist_created = False
    capture = cv2.VideoCapture(1)

    while capture.isOpened():
        pressed_key = cv2.waitKey(1)
        _, frame = capture.read()

        if pressed_key & 0xFF == ord('z'):
            is_hand_hist_created = True
            hand_hist = hand_histogram(frame)

        if is_hand_hist_created:
            manage_image_opr(frame, hand_hist)
            cv2.imshow("Contours", hist_masking(frame, hand_hist))


        else:
            frame = draw_rect(frame)

        cv2.imshow("Live Feed", rescale_frame(frame))

        if pressed_key == 27 or pressed_key == ord('q'):
            break

    cv2.destroyAllWindows()
    capture.release()


if __name__ == '__main__':
    main()
# Out:
# Centroid : (59, 398), farthest Point : (63, 390)
# Centroid : (59, 398), farthest Point : (63, 390)
# Centroid : (47, 433), farthest Point : (53, 430)
# Centroid : (47, 433), farthest Point : (53, 430)
# Centroid : (57, 437), farthest Point : (56, 438)
# Centroid : (57, 437), farthest Point : (56, 438)
# Centroid : (98, 428), farthest Point : (92, 441)
# Centroid : (98, 428), farthest Point : (92, 441)
# Centroid : (332, 241), farthest Point : (156, 0)
# Centroid : (332, 241), farthest Point : (156, 0)
# Centroid : (34, 478), farthest Point : (39, 477)
# Centroid : (34, 478), farthest Point : (39, 477)
# Centroid : (51, 387), farthest Point : (64, 383)
# Centroid : (51, 387), farthest Point : (64, 383)
# Centroid : (93, 347), farthest Point : (98, 340)
# Centroid : (93, 347), farthest Point : (98, 340)
# Centroid : (470, 444), farthest Point : (474, 453)
# Centroid : (470, 444), farthest Point : (474, 453)
# Centroid : (70, 427), farthest Point : (69, 430)
# Centroid : (70, 427), farthest Point : (69, 430)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (81, 353), farthest Point : (80, 355)
# Centroid : (81, 353), farthest Point : (80, 355)
# Centroid : (451, 312), farthest Point : (466, 321)
# Centroid : (451, 312), farthest Point : (466, 321)
# Centroid : (42, 398), farthest Point : (46, 395)
# Centroid : (42, 398), farthest Point : (46, 395)
# Centroid : (422, 459), farthest Point : (406, 462)
# Centroid : (422, 459), farthest Point : (406, 462)
# Centroid : (453, 443), farthest Point : (458, 453)
# Centroid : (453, 443), farthest Point : (458, 453)
# Centroid : (492, 268), farthest Point : (507, 265)
# Centroid : (492, 268), farthest Point : (507, 265)
# Centroid : (180, 475), farthest Point : (194, 478)
# Centroid : (180, 475), farthest Point : (194, 478)
# Centroid : (275, 469), farthest Point : (287, 478)
# Centroid : (275, 469), farthest Point : (287, 478)
# Centroid : (170, 455), farthest Point : (186, 465)
# Centroid : (170, 455), farthest Point : (186, 465)
# Centroid : (290, 472), farthest Point : (309, 477)
# Centroid : (290, 472), farthest Point : (309, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (260, 477), farthest Point : None
# Centroid : (260, 477), farthest Point : None
# Centroid : (236, 472), farthest Point : (213, 479)
# Centroid : (236, 472), farthest Point : (213, 479)
# Centroid : (13, 471), farthest Point : (30, 477)
# Centroid : (13, 471), farthest Point : (30, 477)
# Centroid : (298, 472), farthest Point : (281, 479)
# Centroid : (298, 472), farthest Point : (281, 479)
# Centroid : (301, 478), farthest Point : None
# Centroid : (301, 478), farthest Point : None
# Centroid : (174, 475), farthest Point : (180, 472)
# Centroid : (174, 475), farthest Point : (180, 472)
# Centroid : (234, 477), farthest Point : (240, 477)
# Centroid : (234, 477), farthest Point : (240, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (135, 472), farthest Point : (130, 473)
# Centroid : (135, 472), farthest Point : (130, 473)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (437, 477), farthest Point : (444, 475)
# Centroid : (437, 477), farthest Point : (444, 475)
# Centroid : (457, 477), farthest Point : (461, 475)
# Centroid : (457, 477), farthest Point : (461, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (37, 440), farthest Point : (45, 443)
# Centroid : (37, 440), farthest Point : (45, 443)
# Centroid : (35, 391), farthest Point : (36, 389)
# Centroid : (35, 391), farthest Point : (36, 389)
# Centroid : (10, 468), farthest Point : (25, 478)
# Centroid : (10, 468), farthest Point : (25, 478)
# Centroid : (447, 478), farthest Point : None
# Centroid : (447, 478), farthest Point : None
# Centroid : (456, 478), farthest Point : None
# Centroid : (456, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (2, 476), farthest Point : None
# Centroid : (2, 476), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (479, 472), farthest Point : (481, 472)
# Centroid : (479, 472), farthest Point : (481, 472)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (493, 461), farthest Point : None
# Centroid : (493, 461), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (471, 478), farthest Point : None
# Centroid : (471, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (475, 478), farthest Point : None
# Centroid : (475, 478), farthest Point : None
# Centroid : (464, 478), farthest Point : None
# Centroid : (464, 478), farthest Point : None
# Centroid : (474, 478), farthest Point : None
# Centroid : (474, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (298, 467), farthest Point : None
# Centroid : (298, 467), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (456, 478), farthest Point : None
# Centroid : (456, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (294, 463), farthest Point : None
# Centroid : (294, 463), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (447, 474), farthest Point : (449, 474)
# Centroid : (447, 474), farthest Point : (449, 474)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (416, 477), farthest Point : None
# Centroid : (416, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (184, 474), farthest Point : (170, 477)
# Centroid : (184, 474), farthest Point : (170, 477)
# Centroid : (597, 471), farthest Point : (582, 478)
# Centroid : (597, 471), farthest Point : (582, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (582, 472), farthest Point : (596, 467)
# Centroid : (582, 472), farthest Point : (596, 467)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (572, 475), farthest Point : (555, 476)
# Centroid : (572, 475), farthest Point : (555, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (629, 472), farthest Point : (615, 479)
# Centroid : (629, 472), farthest Point : (615, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (597, 440), farthest Point : (599, 449)
# Centroid : (597, 440), farthest Point : (599, 449)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (462, 473), farthest Point : (461, 475)
# Centroid : (462, 473), farthest Point : (461, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (333, 472), farthest Point : (335, 472)
# Centroid : (333, 472), farthest Point : (335, 472)
# Centroid : (634, 475), farthest Point : (638, 469)
# Centroid : (634, 475), farthest Point : (638, 469)
# Centroid : (350, 478), farthest Point : None
# Centroid : (350, 478), farthest Point : None
# Centroid : (340, 475), farthest Point : (341, 477)
# Centroid : (340, 475), farthest Point : (341, 477)
# Centroid : (334, 474), farthest Point : (337, 476)
# Centroid : (334, 474), farthest Point : (337, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (84, 475), farthest Point : (97, 475)
# Centroid : (84, 475), farthest Point : (97, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (631, 473), farthest Point : (634, 467)
# Centroid : (631, 473), farthest Point : (634, 467)
# Centroid : (506, 460), farthest Point : None
# Centroid : (506, 460), farthest Point : None
# Centroid : (237, 473), farthest Point : (252, 474)
# Centroid : (237, 473), farthest Point : (252, 474)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (294, 460), farthest Point : (297, 462)
# Centroid : (294, 460), farthest Point : (297, 462)
# Centroid : (293, 459), farthest Point : (292, 460)
# Centroid : (293, 459), farthest Point : (292, 460)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (556, 477), farthest Point : (548, 477)
# Centroid : (556, 477), farthest Point : (548, 477)
# Centroid : (308, 459), farthest Point : None
# Centroid : (308, 459), farthest Point : None
# Centroid : (570, 477), farthest Point : (554, 476)
# Centroid : (570, 477), farthest Point : (554, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (300, 460), farthest Point : None
# Centroid : (300, 460), farthest Point : None
# Centroid : (316, 464), farthest Point : None
# Centroid : (316, 464), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (316, 465), farthest Point : (319, 464)
# Centroid : (316, 465), farthest Point : (319, 464)
# Centroid : (322, 469), farthest Point : None
# Centroid : (322, 469), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (309, 462), farthest Point : (307, 459)
# Centroid : (309, 462), farthest Point : (307, 459)
# Centroid : (326, 469), farthest Point : None
# Centroid : (326, 469), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (315, 464), farthest Point : None
# Centroid : (315, 464), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (332, 471), farthest Point : None
# Centroid : (332, 471), farthest Point : None
# Centroid : (626, 477), farthest Point : (632, 475)
# Centroid : (626, 477), farthest Point : (632, 475)
# Centroid : (332, 473), farthest Point : None
# Centroid : (332, 473), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (308, 461), farthest Point : None
# Centroid : (308, 461), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (84, 478), farthest Point : (89, 479)
# Centroid : (84, 478), farthest Point : (89, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (258, 450), farthest Point : (261, 451)
# Centroid : (258, 450), farthest Point : (261, 451)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (8, 468), farthest Point : (18, 479)
# Centroid : (8, 468), farthest Point : (18, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (2, 331), farthest Point : (3, 339)
# Centroid : (2, 331), farthest Point : (3, 339)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (476, 341), farthest Point : (476, 344)
# Centroid : (476, 341), farthest Point : (476, 344)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (513, 477), farthest Point : (514, 479)
# Centroid : (513, 477), farthest Point : (514, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (520, 205), farthest Point : (532, 216)
# Centroid : (520, 205), farthest Point : (532, 216)
# Centroid : (6, 360), farthest Point : (1, 375)
# Centroid : (6, 360), farthest Point : (1, 375)
# Centroid : (574, 266), farthest Point : None
# Centroid : (574, 266), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (554, 447), farthest Point : None
# Centroid : (554, 447), farthest Point : None
# Centroid : (25, 463), farthest Point : (21, 467)
# Centroid : (25, 463), farthest Point : (21, 467)
# Centroid : (620, 455), farthest Point : None
# Centroid : (620, 455), farthest Point : None
# Centroid : (611, 375), farthest Point : None
# Centroid : (611, 375), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (319, 426), farthest Point : (329, 423)
# Centroid : (319, 426), farthest Point : (329, 423)
# Centroid : (395, 466), farthest Point : (377, 473)
# Centroid : (395, 466), farthest Point : (377, 473)
# Centroid : (313, 465), farthest Point : (327, 474)
# Centroid : (313, 465), farthest Point : (327, 474)
# Centroid : (389, 452), farthest Point : (413, 476)
# Centroid : (389, 452), farthest Point : (413, 476)
# Centroid : (376, 468), farthest Point : (391, 477)
# Centroid : (602, 339), farthest Point : None
# Centroid : (602, 339), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (1, 437), farthest Point : (4, 439)
# Centroid : (1, 437), farthest Point : (4, 439)
# Centroid : (19, 314), farthest Point : (1, 380)
# Centroid : (19, 314), farthest Point : (1, 380)
# Centroid : (13, 292), farthest Point : (3, 331)
# Centroid : (13, 292), farthest Point : (3, 331)
# Centroid : None, farthest Point : None
# Centroid : (13, 271), farthest Point : (28, 250)
# Centroid : (13, 271), farthest Point : (28, 250)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (83, 224), farthest Point : None
# Centroid : (350, 385), farthest Point : (361, 400)
# Centroid : None, farthest Point : None
# Centroid : (376, 477), farthest Point : (382, 476)
# Centroid : None, farthest Point : None
# Centroid : (325, 436), farthest Point : (332, 440)
# Centroid : (403, 460), farthest Point : (418, 457)
# Centroid : (361, 396), farthest Point : (376, 406)
# Centroid : (38, 319), farthest Point : (4, 440)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (29, 466), farthest Point : (12, 475)
# Centroid : None, farthest Point : None
# Centroid : (36, 463), farthest Point : (45, 445)
# Centroid : (37, 467), farthest Point : (50, 479)
# Centroid : (282, 264), farthest Point : (297, 261)
# Centroid : (54, 465), farthest Point : (59, 443)
# Centroid : (96, 477), farthest Point : (101, 476)
# Centroid : (165, 239), farthest Point : (166, 237)
# Centroid : (69, 462), farthest Point : (74, 440)
# Centroid : (76, 456), farthest Point : (85, 423)
# Centroid : None, farthest Point : None
# Centroid : (162, 247), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (86, 466), farthest Point : (70, 476)
# Centroid : (88, 460), farthest Point : (97, 436)
# Centroid : (87, 456), farthest Point : (97, 425)
# Centroid : (73, 468), farthest Point : (81, 471)
# Centroid : (71, 459), farthest Point : (78, 438)
# Centroid : (78, 258), farthest Point : (65, 479)
# Centroid : (73, 257), farthest Point : (56, 453)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (30, 427), farthest Point : (25, 429)
# Centroid : None, farthest Point : None
# Centroid : (5, 478), farthest Point : (5, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (1, 422), farthest Point : (1, 427)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (28, 316), farthest Point : (67, 237)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (6, 451), farthest Point : (5, 426)
# Centroid : None, farthest Point : None
# Centroid : (23, 251), farthest Point : None
# Centroid : (13, 310), farthest Point : (3, 395)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (0, 231), farthest Point : (0, 235)
# Centroid : (25, 227), farthest Point : (1, 416)
# Centroid : (3, 247), farthest Point : (0, 247)
# Centroid : None, farthest Point : None
# Centroid : (22, 231), farthest Point : (4, 418)
# Centroid : (22, 231), farthest Point : (4, 418)
# Centroid : None, farthest Point : None
# Centroid : (18, 215), farthest Point : (1, 375)
# Centroid : (16, 205), farthest Point : (1, 349)
# Centroid : (16, 211), farthest Point : (2, 362)
# Centroid : (17, 228), farthest Point : (1, 398)
# Centroid : (19, 242), farthest Point : (1, 429)
# Centroid : (21, 254), farthest Point : (2, 478)
# Centroid : (456, 185), farthest Point : (473, 170)
# Centroid : (456, 185), farthest Point : (473, 170)
# Centroid : (4, 467), farthest Point : (11, 456)
# Centroid : (456, 186), farthest Point : (469, 195)
# Centroid : (21, 358), farthest Point : (23, 479)
# Centroid : (21, 358), farthest Point : (23, 479)
# Centroid : (29, 263), farthest Point : (28, 479)
# Centroid : (29, 264), farthest Point : (30, 479)
# Centroid : (25, 366), farthest Point : (34, 479)
# Centroid : (30, 362), farthest Point : (42, 479)
# Centroid : (34, 366), farthest Point : (51, 479)
# Centroid : (34, 366), farthest Point : (51, 479)
# Centroid : (40, 367), farthest Point : (55, 479)
# Centroid : (40, 367), farthest Point : (55, 479)
# Centroid : (43, 373), farthest Point : (60, 479)
# Centroid : (43, 373), farthest Point : (60, 479)
# Centroid : (47, 371), farthest Point : (0, 270)
# Centroid : (47, 371), farthest Point : (0, 270)
# Centroid : (606, 195), farthest Point : (633, 178)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (616, 193), farthest Point : (617, 208)
# Centroid : (616, 193), farthest Point : (617, 208)
# Centroid : (490, 6), farthest Point : (508, 6)
# Centroid : (0, 250), farthest Point : None
# Centroid : (0, 250), farthest Point : None
# Centroid : (277, 185), farthest Point : (0, 479)
# Centroid : (277, 185), farthest Point : (0, 479)
# Centroid : (64, 364), farthest Point : (206, 299)
# Centroid : (64, 364), farthest Point : (206, 299)
# Centroid : (60, 366), farthest Point : (171, 304)
# Centroid : (60, 366), farthest Point : (171, 304)
# Centroid : None, farthest Point : None
# Centroid : (60, 287), farthest Point : (0, 479)
# Centroid : (60, 287), farthest Point : (0, 479)
# Centroid : (488, 256), farthest Point : (487, 230)
# Centroid : (488, 256), farthest Point : (487, 230)
# Centroid : (60, 367), farthest Point : (172, 298)
# Centroid : (198, 292), farthest Point : (213, 298)
# Centroid : (198, 292), farthest Point : (213, 298)
# Centroid : (61, 365), farthest Point : (173, 312)
# Centroid : (61, 365), farthest Point : (173, 312)
# Centroid : (64, 286), farthest Point : (6, 102)
# Centroid : (64, 286), farthest Point : (6, 102)
# Centroid : None, farthest Point : None
# Centroid : (287, 206), farthest Point : (639, 190)
# Centroid : (287, 206), farthest Point : (639, 190)
# Centroid : (291, 206), farthest Point : (70, 479)
# Centroid : (291, 206), farthest Point : (70, 479)
# Centroid : (579, 193), farthest Point : (580, 195)
# Centroid : (579, 193), farthest Point : (580, 195)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (209, 309), farthest Point : (215, 304)
# Centroid : (78, 277), farthest Point : (80, 280)
# Centroid : (78, 277), farthest Point : (80, 280)
# Centroid : (574, 163), farthest Point : (564, 174)
# Centroid : (574, 163), farthest Point : (564, 174)
# Centroid : (6, 472), farthest Point : (14, 473)
# Centroid : (2, 476), farthest Point : (8, 479)
# Centroid : (2, 476), farthest Point : (8, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (39, 466), farthest Point : (72, 472)
# Centroid : (39, 466), farthest Point : (72, 472)
# Centroid : (72, 357), farthest Point : (223, 316)
# Centroid : (72, 357), farthest Point : (223, 316)
# Centroid : (96, 268), farthest Point : (97, 274)
# Centroid : (68, 472), farthest Point : (73, 474)
# Centroid : (68, 472), farthest Point : (73, 474)
# Centroid : (532, 72), farthest Point : (547, 69)
# Centroid : (532, 72), farthest Point : (547, 69)
# Centroid : (30, 270), farthest Point : (34, 271)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (289, 203), farthest Point : (0, 479)
# Centroid : (289, 203), farthest Point : (0, 479)
# Centroid : (68, 473), farthest Point : (70, 479)
# Centroid : (68, 473), farthest Point : (70, 479)
# Centroid : (591, 154), farthest Point : (612, 150)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (285, 188), farthest Point : (0, 479)
# Centroid : (285, 188), farthest Point : (0, 479)
# Centroid : (172, 294), farthest Point : (190, 290)
# Centroid : (172, 294), farthest Point : (190, 290)
# Centroid : (53, 366), farthest Point : (0, 479)
# Centroid : (46, 365), farthest Point : (0, 479)
# Centroid : (46, 365), farthest Point : (0, 479)
# Centroid : None, farthest Point : None
# Centroid : (34, 454), farthest Point : (42, 458)
# Centroid : (34, 454), farthest Point : (42, 458)
# Centroid : (84, 270), farthest Point : (90, 270)
# Centroid : (84, 270), farthest Point : (90, 270)
# Centroid : None, farthest Point : None
# Centroid : (0, 401), farthest Point : None
# Centroid : (0, 401), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (16, 450), farthest Point : (12, 421)
# Centroid : (16, 450), farthest Point : (12, 421)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (5, 456), farthest Point : (1, 473)
# Centroid : (5, 456), farthest Point : (1, 473)
# Centroid : (10, 374), farthest Point : (0, 387)
# Centroid : (9, 437), farthest Point : (1, 464)
# Centroid : (10, 372), farthest Point : (2, 399)
# Centroid : (10, 372), farthest Point : (2, 399)
# Centroid : (7, 386), farthest Point : (5, 370)
# Centroid : (8, 384), farthest Point : (4, 366)
# Centroid : (0, 246), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (90, 470), farthest Point : (103, 479)
# Centroid : (90, 470), farthest Point : (103, 479)
# Centroid : (89, 399), farthest Point : None
# Centroid : (88, 433), farthest Point : (79, 446)
# Centroid : None, farthest Point : None
# Centroid : (67, 431), farthest Point : None
# Centroid : (67, 431), farthest Point : None
# Centroid : (68, 444), farthest Point : (60, 469)
# Centroid : (58, 471), farthest Point : (66, 472)
# Centroid : (65, 453), farthest Point : (55, 467)
# Centroid : (65, 453), farthest Point : (55, 467)
# Centroid : (63, 466), farthest Point : (75, 479)
# Centroid : None, farthest Point : None
# Centroid : (61, 470), farthest Point : (69, 470)
# Centroid : (62, 460), farthest Point : (53, 472)
# Centroid : None, farthest Point : None
# Centroid : (63, 431), farthest Point : (69, 414)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (59, 465), farthest Point : (71, 479)
# Centroid : (59, 465), farthest Point : (70, 479)
# Centroid : (56, 471), farthest Point : (65, 468)
# Centroid : (62, 443), farthest Point : (48, 478)
# Centroid : (62, 443), farthest Point : (48, 478)
# Centroid : (64, 432), farthest Point : (54, 445)
# Centroid : (56, 441), farthest Point : (50, 456)
# Centroid : (44, 309), farthest Point : (92, 194)
# Centroid : (46, 454), farthest Point : (40, 469)
# Centroid : (46, 454), farthest Point : (40, 469)
# Centroid : (46, 430), farthest Point : (40, 445)
# Centroid : (58, 230), farthest Point : None
# Centroid : (43, 471), farthest Point : (58, 477)
# Centroid : (43, 471), farthest Point : (58, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (43, 462), farthest Point : (56, 478)
# Centroid : (43, 478), farthest Point : (48, 479)
# Centroid : (43, 478), farthest Point : (48, 479)
# Centroid : (38, 461), farthest Point : (33, 447)
# Centroid : None, farthest Point : None
# Centroid : (42, 474), farthest Point : (57, 479)
# Centroid : (42, 474), farthest Point : (57, 479)
# Centroid : (46, 453), farthest Point : (36, 466)
# Centroid : (48, 449), farthest Point : (42, 473)
# Centroid : (48, 454), farthest Point : (48, 427)
# Centroid : (49, 460), farthest Point : (61, 479)
# Centroid : (49, 456), farthest Point : (42, 425)
# Centroid : (49, 456), farthest Point : (42, 425)
# Centroid : None, farthest Point : None
# Centroid : (49, 458), farthest Point : (40, 441)
# Centroid : (248, 324), farthest Point : (252, 306)
# Centroid : (248, 324), farthest Point : (252, 306)
# Centroid : (50, 450), farthest Point : (40, 438)
# Centroid : (48, 467), farthest Point : (60, 479)
# Centroid : (47, 459), farthest Point : (61, 467)
# Centroid : (47, 477), farthest Point : (52, 476)
# Centroid : (42, 473), farthest Point : (37, 476)
# Centroid : (42, 473), farthest Point : (37, 476)
# Centroid : (48, 467), farthest Point : (57, 479)
# Centroid : (47, 469), farthest Point : (60, 479)
# Centroid : (49, 441), farthest Point : (40, 453)
# Centroid : (47, 453), farthest Point : (48, 429)
# Centroid : (47, 453), farthest Point : (48, 429)
# Centroid : (38, 473), farthest Point : (47, 476)
# Centroid : (43, 466), farthest Point : (33, 452)
# Centroid : (56, 227), farthest Point : None
# Centroid : (56, 227), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (51, 223), farthest Point : (52, 228)
# Centroid : (32, 468), farthest Point : (46, 478)
# Centroid : (34, 473), farthest Point : (48, 477)
# Centroid : (29, 454), farthest Point : (23, 469)
# Centroid : (29, 454), farthest Point : (23, 469)
# Centroid : None, farthest Point : None
# Centroid : (26, 470), farthest Point : (21, 459)
# Centroid : (31, 467), farthest Point : (43, 479)
# Centroid : (31, 467), farthest Point : (43, 479)
# Centroid : (31, 466), farthest Point : (20, 455)
# Centroid : None, farthest Point : None
# Centroid : (28, 474), farthest Point : (42, 478)
# Centroid : (29, 469), farthest Point : (41, 479)
# Centroid : (258, 343), farthest Point : (273, 340)
# Centroid : (258, 343), farthest Point : (273, 340)
# Centroid : (29, 464), farthest Point : (40, 479)
# Centroid : (205, 323), farthest Point : (220, 320)
# Centroid : None, farthest Point : None
# Centroid : (360, 291), farthest Point : (375, 288)
# Centroid : (360, 291), farthest Point : (375, 288)
# Centroid : (26, 468), farthest Point : (40, 479)
# Centroid : (26, 477), farthest Point : (31, 475)
# Centroid : (21, 472), farthest Point : (28, 469)
# Centroid : (21, 472), farthest Point : (28, 469)
# Centroid : (299, 277), farthest Point : (314, 274)
# Centroid : (299, 277), farthest Point : (314, 274)
# Centroid : (23, 313), farthest Point : (25, 399)
# Centroid : None, farthest Point : None
# Centroid : (26, 423), farthest Point : (21, 408)
# Centroid : (26, 423), farthest Point : (21, 408)
# Centroid : None, farthest Point : None
# Centroid : (204, 346), farthest Point : (213, 351)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (24, 405), farthest Point : (32, 403)
# Centroid : (20, 428), farthest Point : (28, 426)
# Centroid : (25, 429), farthest Point : (17, 456)
# Centroid : (25, 429), farthest Point : (17, 456)
# Centroid : (24, 427), farthest Point : (12, 457)
# Centroid : None, farthest Point : None
# Centroid : (208, 349), farthest Point : (217, 360)
# Centroid : (208, 349), farthest Point : (217, 360)
# Centroid : None, farthest Point : None
# Centroid : (19, 429), farthest Point : (26, 432)
# Centroid : (21, 424), farthest Point : (12, 438)
# Centroid : (22, 330), farthest Point : (21, 453)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (24, 425), farthest Point : (12, 453)
# Centroid : (24, 431), farthest Point : (13, 446)
# Centroid : (23, 434), farthest Point : (13, 446)
# Centroid : (23, 430), farthest Point : (16, 409)
# Centroid : (23, 430), farthest Point : (16, 409)
# Centroid : (22, 435), farthest Point : (10, 471)
# Centroid : (233, 345), farthest Point : (248, 342)
# Centroid : (24, 430), farthest Point : (16, 452)
# Centroid : (24, 430), farthest Point : (16, 452)
# Centroid : (24, 427), farthest Point : (13, 441)
# Centroid : (24, 424), farthest Point : (23, 406)
# Centroid : (24, 428), farthest Point : (23, 410)
# Centroid : (22, 415), farthest Point : (15, 430)
# Centroid : (23, 434), farthest Point : (13, 446)
# Centroid : (23, 434), farthest Point : (13, 446)
# Centroid : (16, 445), farthest Point : (19, 445)
# Centroid : (23, 433), farthest Point : (23, 409)
# Centroid : (22, 428), farthest Point : (35, 429)
# Centroid : (22, 428), farthest Point : (35, 429)
# Centroid : (22, 437), farthest Point : (12, 450)
# Centroid : (18, 425), farthest Point : (10, 437)
# Centroid : (16, 430), farthest Point : (15, 445)
# Centroid : (16, 423), farthest Point : (10, 435)
# Centroid : (10, 473), farthest Point : (18, 475)
# Centroid : (10, 473), farthest Point : (18, 475)
# Centroid : None, farthest Point : None
# Centroid : (11, 446), farthest Point : (7, 442)
# Centroid : (21, 429), farthest Point : (20, 406)
# Centroid : (20, 436), farthest Point : (9, 448)
# Centroid : (20, 436), farthest Point : (9, 448)
# Centroid : (20, 430), farthest Point : (14, 414)
# Centroid : (19, 437), farthest Point : (9, 449)
# Centroid : (21, 425), farthest Point : (13, 448)
# Centroid : (21, 425), farthest Point : (13, 448)
# Centroid : None, farthest Point : None
# Centroid : (6, 476), farthest Point : None
# Centroid : (16, 428), farthest Point : (12, 411)
# Centroid : (15, 428), farthest Point : (8, 435)
# Centroid : (188, 357), farthest Point : (193, 372)
# Centroid : (188, 357), farthest Point : (193, 372)
# Centroid : (20, 433), farthest Point : (12, 458)
# Centroid : (19, 430), farthest Point : (14, 405)
# Centroid : (15, 472), farthest Point : (29, 474)
# Centroid : (15, 472), farthest Point : (29, 474)
# Centroid : (18, 434), farthest Point : (17, 411)
# Centroid : (18, 436), farthest Point : (6, 452)
# Centroid : (386, 478), farthest Point : (391, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (21, 318), farthest Point : (25, 436)
# Centroid : (14, 464), farthest Point : (8, 479)
# Centroid : (22, 425), farthest Point : (22, 449)
# Centroid : (22, 447), farthest Point : (16, 412)
# Centroid : (22, 447), farthest Point : (16, 412)
# Centroid : (26, 428), farthest Point : (16, 442)
# Centroid : (28, 418), farthest Point : (18, 433)
# Centroid : (24, 443), farthest Point : (16, 444)
# Centroid : (28, 423), farthest Point : (20, 450)
# Centroid : (28, 423), farthest Point : (20, 450)
# Centroid : None, farthest Point : None
# Centroid : (222, 473), farthest Point : (237, 477)
# Centroid : (24, 474), farthest Point : (38, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (25, 460), farthest Point : (39, 460)
# Centroid : (19, 472), farthest Point : (26, 470)
# Centroid : (22, 433), farthest Point : (30, 420)
# Centroid : (22, 433), farthest Point : (30, 420)
# Centroid : (20, 327), farthest Point : (21, 453)
# Centroid : (21, 432), farthest Point : (35, 434)
# Centroid : (18, 438), farthest Point : (32, 440)
# Centroid : (16, 429), farthest Point : (6, 453)
# Centroid : (12, 409), farthest Point : (20, 406)
# Centroid : (12, 409), farthest Point : (20, 406)
# Centroid : (13, 426), farthest Point : (1, 454)
# Centroid : (6, 438), farthest Point : (4, 453)
# Centroid : (8, 452), farthest Point : (0, 467)
# Centroid : (8, 452), farthest Point : (0, 467)
# Centroid : (176, 369), farthest Point : (191, 366)
# Centroid : (6, 442), farthest Point : (1, 457)
# Centroid : None, farthest Point : None
# Centroid : (12, 274), farthest Point : (3, 323)
# Centroid : (8, 310), farthest Point : (0, 324)
# Centroid : (8, 310), farthest Point : (0, 324)
# Centroid : (6, 250), farthest Point : (4, 236)
# Centroid : None, farthest Point : None
# Centroid : (4, 210), farthest Point : (3, 213)
# Centroid : (443, 478), farthest Point : (448, 477)
# Centroid : (443, 478), farthest Point : (448, 477)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (5, 239), farthest Point : (4, 253)
# Centroid : (5, 239), farthest Point : (4, 253)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (0, 203), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (467, 222), farthest Point : (465, 231)
# Centroid : (467, 222), farthest Point : (465, 231)
# Centroid : (5, 238), farthest Point : (11, 248)
# Centroid : (4, 189), farthest Point : (9, 182)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (28, 370), farthest Point : (43, 367)
# Centroid : (6, 216), farthest Point : (0, 234)
# Centroid : None, farthest Point : None
# Centroid : (165, 405), farthest Point : (180, 402)
# Centroid : (165, 405), farthest Point : (180, 402)
# Centroid : None, farthest Point : None
# Centroid : (0, 224), farthest Point : None
# Centroid : (7, 239), farthest Point : (0, 260)
# Centroid : (7, 227), farthest Point : (3, 209)
# Centroid : (7, 227), farthest Point : (3, 209)
# Centroid : (280, 321), farthest Point : (276, 307)
# Centroid : (469, 356), farthest Point : (236, 247)
# Centroid : (468, 360), farthest Point : (236, 260)
# Centroid : (468, 363), farthest Point : (230, 276)
# Centroid : (468, 363), farthest Point : (230, 276)
# Centroid : (468, 362), farthest Point : (229, 272)
# Centroid : (468, 359), farthest Point : (229, 262)
# Centroid : (470, 356), farthest Point : (232, 253)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (471, 344), farthest Point : (243, 208)
# Centroid : (471, 337), farthest Point : (253, 182)
# Centroid : (8, 220), farthest Point : (2, 201)
# Centroid : (8, 220), farthest Point : (2, 201)
# Centroid : (512, 199), farthest Point : (540, 192)
# Centroid : (506, 202), farthest Point : (523, 199)
# Centroid : (487, 478), farthest Point : (492, 479)
# Centroid : (5, 230), farthest Point : (2, 244)
# Centroid : (0, 173), farthest Point : None
# Centroid : (0, 173), farthest Point : None
# Centroid : (492, 199), farthest Point : (492, 202)
# Centroid : (3, 238), farthest Point : (9, 236)
# Centroid : (479, 345), farthest Point : (273, 196)
# Centroid : None, farthest Point : None
# Centroid : (5, 232), farthest Point : (3, 246)
# Centroid : (5, 238), farthest Point : (14, 240)
# Centroid : (480, 345), farthest Point : (273, 198)
# Centroid : (480, 347), farthest Point : (271, 205)
# Centroid : (480, 347), farthest Point : (271, 205)
# Centroid : (480, 348), farthest Point : (274, 202)
# Centroid : (480, 348), farthest Point : (271, 204)
# Centroid : (148, 362), farthest Point : (144, 349)
# Centroid : (479, 346), farthest Point : (271, 194)
# Centroid : (479, 346), farthest Point : (271, 194)
# Centroid : (152, 360), farthest Point : (167, 357)
# Centroid : (480, 339), farthest Point : (286, 161)
# Centroid : (464, 183), farthest Point : (466, 180)
# Centroid : (464, 183), farthest Point : (466, 180)
# Centroid : (519, 201), farthest Point : (534, 198)
# Centroid : (479, 369), farthest Point : (234, 359)
# Centroid : (476, 377), farthest Point : (232, 360)
# Centroid : (476, 376), farthest Point : (233, 327)
# Centroid : (475, 370), farthest Point : (246, 286)
# Centroid : (475, 362), farthest Point : (249, 242)
# Centroid : (474, 355), farthest Point : (257, 215)
# Centroid : (294, 337), farthest Point : (295, 341)
# Centroid : (470, 348), farthest Point : (240, 215)
# Centroid : (469, 352), farthest Point : (226, 248)
# Centroid : (469, 355), farthest Point : (224, 261)
# Centroid : (469, 358), farthest Point : (220, 275)
# Centroid : (467, 359), farthest Point : (218, 279)
# Centroid : (467, 359), farthest Point : (218, 279)
# Centroid : (468, 359), farthest Point : (220, 268)
# Centroid : (470, 356), farthest Point : (227, 250)
# Centroid : (144, 394), farthest Point : (159, 391)
# Centroid : (470, 346), farthest Point : (238, 204)
# Centroid : (470, 346), farthest Point : (238, 204)
# Centroid : (470, 346), farthest Point : (237, 210)
# Centroid : (471, 353), farthest Point : (226, 253)
# Centroid : (470, 356), farthest Point : (222, 266)
# Centroid : (471, 357), farthest Point : (220, 280)
# Centroid : (470, 357), farthest Point : (219, 286)
# Centroid : (470, 357), farthest Point : (219, 286)
# Centroid : None, farthest Point : None
# Centroid : (473, 348), farthest Point : (228, 244)
# Centroid : (473, 342), farthest Point : (228, 227)
# Centroid : (473, 342), farthest Point : (228, 227)
# Centroid : (7, 220), farthest Point : (2, 205)
# Centroid : (473, 344), farthest Point : (231, 225)
# Centroid : (473, 349), farthest Point : (224, 252)
# Centroid : (473, 349), farthest Point : (224, 252)
# Centroid : (472, 351), farthest Point : (221, 262)
# Centroid : (472, 349), farthest Point : (220, 258)
# Centroid : (473, 344), farthest Point : (220, 243)
# Centroid : None, farthest Point : None
# Centroid : (475, 205), farthest Point : (477, 202)
# Centroid : (475, 205), farthest Point : (477, 202)
# Centroid : (470, 330), farthest Point : (220, 211)
# Centroid : (471, 338), farthest Point : (219, 244)
# Centroid : (470, 348), farthest Point : (213, 265)
# Centroid : (470, 348), farthest Point : (213, 265)
# Centroid : (473, 352), farthest Point : (220, 257)
# Centroid : (474, 349), farthest Point : (242, 214)
# Centroid : (474, 348), farthest Point : (247, 203)
# Centroid : (506, 210), farthest Point : (523, 215)
# Centroid : (522, 207), farthest Point : (535, 216)
# Centroid : (522, 207), farthest Point : (535, 216)
# Centroid : (474, 347), farthest Point : (241, 212)
# Centroid : (477, 343), farthest Point : (248, 203)
# Centroid : (470, 195), farthest Point : (486, 192)
# Centroid : (483, 337), farthest Point : (276, 165)
# Centroid : (483, 337), farthest Point : (276, 165)
# Centroid : (474, 478), farthest Point : (480, 477)
# Centroid : (520, 200), farthest Point : (487, 209)
# Centroid : (151, 368), farthest Point : (164, 368)
# Centroid : (151, 368), farthest Point : (164, 368)
# Centroid : (294, 327), farthest Point : (309, 324)
# Centroid : (294, 327), farthest Point : (309, 324)
# Centroid : (464, 212), farthest Point : (479, 209)
# Centroid : (513, 203), farthest Point : (487, 201)
# Centroid : (298, 366), farthest Point : (313, 363)
# Centroid : (298, 366), farthest Point : (313, 363)
# Centroid : None, farthest Point : None
# Centroid : (493, 343), farthest Point : (293, 207)
# Centroid : (493, 352), farthest Point : (272, 264)
# Centroid : (493, 352), farthest Point : (272, 264)
# Centroid : (495, 353), farthest Point : (275, 254)
# Centroid : (494, 351), farthest Point : (282, 228)
# Centroid : (494, 349), farthest Point : (284, 219)
# Centroid : (493, 348), farthest Point : (288, 208)
# Centroid : (493, 348), farthest Point : (279, 223)
# Centroid : (493, 348), farthest Point : (279, 223)
# Centroid : (492, 352), farthest Point : (269, 255)
# Centroid : (494, 352), farthest Point : (274, 253)
# Centroid : (494, 345), farthest Point : (284, 216)
# Centroid : (495, 338), farthest Point : (293, 183)
# Centroid : (495, 338), farthest Point : (293, 183)
# Centroid : (523, 204), farthest Point : (499, 223)
# Centroid : (638, 478), farthest Point : None
# Centroid : (226, 311), farthest Point : (241, 308)
# Centroid : (496, 354), farthest Point : (283, 300)
# Centroid : (491, 360), farthest Point : (261, 314)
# Centroid : (491, 360), farthest Point : (261, 314)
# Centroid : (492, 359), farthest Point : (263, 295)
# Centroid : (493, 358), farthest Point : (264, 284)
# Centroid : (150, 362), farthest Point : (165, 359)
# Centroid : (150, 362), farthest Point : (165, 359)
# Centroid : (491, 348), farthest Point : (267, 232)
# Centroid : (492, 344), farthest Point : (275, 213)
# Centroid : (491, 343), farthest Point : (282, 196)
# Centroid : (491, 343), farthest Point : (282, 196)
# Centroid : (495, 351), farthest Point : (276, 272)
# Centroid : (491, 355), farthest Point : (261, 293)
# Centroid : (492, 354), farthest Point : (261, 285)
# Centroid : (493, 353), farthest Point : (264, 265)
# Centroid : (493, 348), farthest Point : (266, 244)
# Centroid : (493, 348), farthest Point : (266, 244)
# Centroid : (493, 349), farthest Point : (270, 240)
# Centroid : (491, 351), farthest Point : (261, 269)
# Centroid : (492, 351), farthest Point : (260, 268)
# Centroid : (492, 351), farthest Point : (260, 268)
# Centroid : (495, 348), farthest Point : (273, 244)
# Centroid : None, farthest Point : None
# Centroid : (523, 209), farthest Point : (528, 218)
# Centroid : (493, 347), farthest Point : (276, 242)
# Centroid : (496, 358), farthest Point : (263, 324)
# Centroid : (496, 358), farthest Point : (263, 324)
# Centroid : (494, 360), farthest Point : (262, 319)
# Centroid : (495, 358), farthest Point : (262, 287)
# Centroid : (494, 353), farthest Point : (266, 253)
# Centroid : (493, 346), farthest Point : (271, 224)
# Centroid : (493, 346), farthest Point : (271, 224)
# Centroid : (492, 345), farthest Point : (271, 220)
# Centroid : (492, 350), farthest Point : (263, 255)
# Centroid : (491, 352), farthest Point : (256, 274)
# Centroid : (491, 352), farthest Point : (256, 274)
# Centroid : (491, 349), farthest Point : (264, 243)
# Centroid : (490, 347), farthest Point : (265, 230)
# Centroid : (491, 352), farthest Point : (265, 250)
# Centroid : (492, 363), farthest Point : (257, 341)
# Centroid : (495, 363), farthest Point : (268, 312)
# Centroid : (495, 363), farthest Point : (268, 312)
# Centroid : (493, 355), farthest Point : (268, 254)
# Centroid : (517, 208), farthest Point : (522, 213)
# Centroid : (165, 385), farthest Point : (171, 396)
# Centroid : (165, 385), farthest Point : (171, 396)
# Centroid : (492, 350), farthest Point : (274, 259)
# Centroid : (152, 377), farthest Point : (141, 388)
# Centroid : (491, 361), farthest Point : (257, 323)
# Centroid : (494, 359), farthest Point : (262, 299)
# Centroid : (493, 353), farthest Point : (265, 258)
# Centroid : (493, 353), farthest Point : (265, 258)
# Centroid : (492, 347), farthest Point : (264, 236)
# Centroid : (492, 349), farthest Point : (266, 243)
# Centroid : (491, 356), farthest Point : (256, 301)
# Centroid : (492, 355), farthest Point : (256, 291)
# Centroid : (492, 355), farthest Point : (256, 291)
# Centroid : (492, 352), farthest Point : (261, 259)
# Centroid : (492, 347), farthest Point : (265, 235)
# Centroid : (491, 343), farthest Point : (274, 206)
# Centroid : (491, 342), farthest Point : (276, 199)
# Centroid : (492, 342), farthest Point : (277, 200)
# ...
# Centroid : (508, 348), farthest Point : (293, 273)
# Centroid : (509, 343), farthest Point : (303, 234)
# Centroid : (509, 343), farthest Point : (303, 234)
# Centroid : (508, 339), farthest Point : (299, 219)
# Centroid : (506, 341), farthest Point : (302, 226)
# Centroid : (506, 349), farthest Point : (288, 296)
# Centroid : (506, 349), farthest Point : (288, 296)
# Centroid : (506, 351), farthest Point : (286, 291)
# Centroid : (506, 351), farthest Point : (287, 286)
# Centroid : (508, 345), farthest Point : (299, 244)
# Centroid : (506, 340), farthest Point : (293, 226)
# Centroid : (507, 345), farthest Point : (293, 255)
# Centroid : (505, 350), farthest Point : (284, 287)
# Centroid : (506, 350), farthest Point : (287, 282)
# Centroid : (507, 347), farthest Point : (287, 262)
# Centroid : (505, 344), farthest Point : (286, 252)
# Centroid : (505, 344), farthest Point : (286, 252)
# Centroid : (505, 346), farthest Point : (284, 265)
# Centroid : (505, 346), farthest Point : (283, 272)
# Centroid : (507, 345), farthest Point : (286, 261)
# Centroid : (507, 340), farthest Point : (294, 231)
# Centroid : (507, 333), farthest Point : (302, 201)
# Centroid : (507, 333), farthest Point : (302, 201)
# Centroid : (485, 205), farthest Point : (486, 208)
# Centroid : (507, 343), farthest Point : (292, 250)
# Centroid : (505, 345), farthest Point : (285, 271)
# Centroid : (505, 345), farthest Point : (285, 271)
# Centroid : (507, 345), farthest Point : (286, 263)
# Centroid : (506, 342), farthest Point : (287, 250)
# Centroid : (506, 341), farthest Point : (286, 248)
# Centroid : (506, 341), farthest Point : (286, 248)
# Centroid : (506, 340), farthest Point : (286, 252)
# Centroid : (508, 339), farthest Point : (287, 256)
# Centroid : (507, 345), farthest Point : (286, 291)
# Centroid : (510, 345), farthest Point : (291, 283)
# Centroid : (120, 354), farthest Point : (135, 351)
# Centroid : (120, 354), farthest Point : (135, 351)
# Centroid : (507, 339), farthest Point : (302, 224)
# Centroid : (515, 355), farthest Point : (335, 321)
# Centroid : (518, 372), farthest Point : (343, 412)
# Centroid : (524, 384), farthest Point : (372, 474)
# Centroid : (524, 384), farthest Point : (372, 474)
# Centroid : (536, 391), farthest Point : (388, 464)
# Centroid : (550, 398), farthest Point : (409, 471)
# Centroid : (565, 403), farthest Point : (439, 472)
# Centroid : (584, 408), farthest Point : (635, 300)
# Centroid : (627, 381), farthest Point : (632, 340)
# Centroid : (11, 131), farthest Point : (3, 169)
# Centroid : (12, 158), farthest Point : (5, 240)
# Centroid : (15, 215), farthest Point : (0, 385)
# Centroid : (15, 215), farthest Point : (0, 385)
# Centroid : (22, 244), farthest Point : (2, 455)
# Centroid : (32, 255), farthest Point : (18, 479)
# Centroid : (44, 264), farthest Point : (38, 478)
# Centroid : (44, 264), farthest Point : (38, 478)
# Centroid : (62, 262), farthest Point : (69, 478)
# Centroid : (62, 262), farthest Point : (69, 478)
# Centroid : None, farthest Point : None
# Centroid : (59, 465), farthest Point : (86, 476)
# Centroid : (165, 345), farthest Point : (588, 475)
# Centroid : (165, 345), farthest Point : (588, 475)
# Centroid : (222, 458), farthest Point : (214, 471)
# Centroid : (230, 359), farthest Point : (639, 427)
# Centroid : (328, 249), farthest Point : (324, 259)
# Centroid : (328, 249), farthest Point : (324, 259)
# Centroid : (49, 475), farthest Point : (53, 472)
# Centroid : (171, 464), farthest Point : (119, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (244, 364), farthest Point : (639, 419)
# Centroid : (244, 364), farthest Point : (639, 419)
# Centroid : (502, 476), farthest Point : None
# Centroid : (142, 467), farthest Point : (155, 477)
# Centroid : (109, 478), farthest Point : (114, 479)
# Centroid : (452, 477), farthest Point : (461, 477)
# Centroid : (452, 477), farthest Point : (461, 477)
# Centroid : (164, 470), farthest Point : (173, 479)
# Centroid : (490, 431), farthest Point : (509, 439)
# Centroid : (490, 431), farthest Point : (509, 439)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (636, 477), farthest Point : (638, 476)
# Centroid : (636, 477), farthest Point : (638, 476)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (216, 473), farthest Point : (231, 475)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (584, 473), farthest Point : (601, 478)
# Centroid : None, farthest Point : None
# Centroid : (596, 476), farthest Point : (602, 474)
# Centroid : (596, 476), farthest Point : (602, 474)
# Centroid : (553, 468), farthest Point : (556, 467)
# Centroid : (553, 468), farthest Point : (556, 467)
# Centroid : (542, 471), farthest Point : (550, 473)
# Centroid : (542, 471), farthest Point : (550, 473)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (568, 436), farthest Point : (579, 448)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (593, 450), farthest Point : (598, 451)
# Centroid : (593, 450), farthest Point : (598, 451)
# Centroid : (634, 468), farthest Point : (627, 470)
# Centroid : (634, 468), farthest Point : (627, 470)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (480, 477), farthest Point : (482, 476)
# Centroid : (480, 441), farthest Point : (481, 448)
# Centroid : (480, 441), farthest Point : (481, 448)
# Centroid : (565, 464), farthest Point : (569, 464)
# Centroid : (565, 464), farthest Point : (569, 464)
# Centroid : (540, 470), farthest Point : None
# Centroid : (540, 470), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (380, 476), farthest Point : (385, 474)
# Centroid : (380, 476), farthest Point : (385, 474)
# Centroid : (391, 372), farthest Point : (404, 373)
# Centroid : (391, 372), farthest Point : (404, 373)
# Centroid : (349, 411), farthest Point : (364, 408)
# Centroid : (349, 411), farthest Point : (364, 408)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (170, 411), farthest Point : (423, 475)
# Centroid : (170, 411), farthest Point : (423, 475)
# Centroid : (126, 414), farthest Point : (321, 479)
# Centroid : (126, 414), farthest Point : (321, 479)
# Centroid : (156, 423), farthest Point : (154, 423)
# Centroid : (156, 423), farthest Point : (154, 423)
# Centroid : (225, 161), farthest Point : (219, 178)
# Centroid : (225, 161), farthest Point : (219, 178)
# Centroid : (103, 81), farthest Point : (0, 3)
# Centroid : (103, 81), farthest Point : (0, 3)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (47, 458), farthest Point : (137, 479)
# Centroid : (47, 458), farthest Point : (137, 479)
# Centroid : (39, 461), farthest Point : (115, 478)
# Centroid : (39, 461), farthest Point : (115, 478)
# Centroid : (43, 436), farthest Point : (44, 436)
# Centroid : (43, 436), farthest Point : (44, 436)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (30, 466), farthest Point : (86, 477)
# Centroid : (30, 466), farthest Point : (86, 477)
# Centroid : (19, 470), farthest Point : (55, 476)
# Centroid : (19, 470), farthest Point : (55, 476)
# Centroid : (169, 409), farthest Point : (179, 406)
# Centroid : (169, 409), farthest Point : (179, 406)
# Centroid : (189, 413), farthest Point : (205, 411)
# Centroid : (189, 413), farthest Point : (205, 411)
# Centroid : (254, 434), farthest Point : (256, 436)
# Centroid : (254, 434), farthest Point : (256, 436)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (189, 426), farthest Point : (202, 425)
# Centroid : (189, 426), farthest Point : (202, 425)
# Centroid : (19, 394), farthest Point : None
# Centroid : (19, 394), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (382, 455), farthest Point : (389, 454)
# Centroid : (382, 455), farthest Point : (389, 454)
# Centroid : (293, 439), farthest Point : (305, 451)
# Centroid : (293, 439), farthest Point : (305, 451)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (563, 448), farthest Point : (566, 450)
# Centroid : (563, 448), farthest Point : (566, 450)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (582, 453), farthest Point : None
# Centroid : (582, 453), farthest Point : None
# Centroid : (332, 431), farthest Point : (339, 430)
# Centroid : (332, 431), farthest Point : (339, 430)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (634, 442), farthest Point : (628, 451)
# Centroid : (634, 442), farthest Point : (628, 451)
# Centroid : (313, 448), farthest Point : (294, 450)
# Centroid : (313, 448), farthest Point : (294, 450)
# Centroid : (155, 445), farthest Point : (156, 445)
# Centroid : (155, 445), farthest Point : (156, 445)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (256, 478), farthest Point : None
# Centroid : (256, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (175, 474), farthest Point : (176, 472)
# Centroid : (175, 474), farthest Point : (176, 472)
# Centroid : (187, 478), farthest Point : None
# Centroid : (187, 478), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (637, 477), farthest Point : None
# Centroid : (637, 477), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (343, 475), farthest Point : (331, 475)
# Centroid : (343, 475), farthest Point : (331, 475)
# Centroid : (370, 478), farthest Point : (375, 478)
# Centroid : (370, 478), farthest Point : (375, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (305, 473), farthest Point : (331, 476)
# Centroid : (305, 473), farthest Point : (331, 476)
# Centroid : (262, 466), farthest Point : None
# Centroid : (262, 466), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (596, 477), farthest Point : (600, 479)
# Centroid : (596, 477), farthest Point : (600, 479)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (76, 478), farthest Point : (81, 477)
# Centroid : (76, 478), farthest Point : (81, 477)
# Centroid : (315, 465), farthest Point : (291, 471)
# Centroid : (315, 465), farthest Point : (291, 471)
# Centroid : (357, 474), farthest Point : (371, 478)
# Centroid : (357, 474), farthest Point : (371, 478)
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : (588, 476), farthest Point : None
# Centroid : (588, 476), farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None
# Centroid : None, farthest Point : None

# %%
"""
Hand gesture recognition
==========================
This is main function for the project.
Source Code:
https://github.com/RobinCPC/CE264-Computer_Vision
Usage:
------
    gesture_hci.py [<video source>] (default: 0)
Keys:
-----
    ESC     - exit
    c       - toggle mouse control (default: False)
    t       - toggle hand tracking (default: False)
    s       - toggle skin calibration (need debug)
"""

import cv2
import numpy as np
import math
import time

# for controlling mouse and keyboard
import pyautogui
import sys

# Fail-safe mode (prevent from ou of control)
pyautogui.FAILSAFE = True
pyautogui.PAUSE = 0.1       # pause each pyautogui function 0.1 sec


# Build fixed-length Queue
class FixedQueue:
    """
    A container with First-In-First-Out (FIFO) queuing policy
    But can only storage maximum number of items in container
    """
    def __init__(self):
        self.list = []
        self.max_item = 5
        self.n_maj = 4

    def __str__(self):
        """Return list as string for printing"""
        return str(self.list)

    def push(self, item):
        """Enqueue the item into the queue, but check length before add in"""
        if self.list.__len__() == self.max_item:
            self.list.pop()
        self.list.insert(0, item)

    def pop(self):
        """Dequeue the earliest enqueued item still in the queue."""
        return self.list.pop()

    def major(self):
        """Return the number that shows often in list"""
        maj = 0
        count = 0
        for i in xrange(5):
            cur_cnt = self.list.count(i)
            if cur_cnt > count:
                maj = i
                count = cur_cnt
        return maj

    def count(self, value):
        """Return how many times that value show up in the queue"""
        return self.list.count(value)

    def isEmpty(self):
        """Return true if the queue is empty"""
        return len(self.list) == 0


# Dummy callback for trackbar
def nothing(x):
    pass

# uncomment if want to do on-line skin calibration
cv2.namedWindow('YRB_calib')
cv2.createTrackbar('Ymin', 'YRB_calib', 54, 255, nothing)
cv2.createTrackbar('Ymax', 'YRB_calib', 143, 255, nothing)
cv2.createTrackbar('CRmin', 'YRB_calib', 131, 255, nothing)
cv2.createTrackbar('CRmax', 'YRB_calib', 157, 255, nothing)
cv2.createTrackbar('CBmin', 'YRB_calib', 110, 255, nothing)
cv2.createTrackbar('CBmax', 'YRB_calib', 155, 255, nothing)

# Main part of gesture_hci
class App(object):
    def __init__(self, video_src):
        self.cam = cv2.VideoCapture(video_src)
        ret, self.frame = self.cam.read()
        cv2.namedWindow('gesture_hci')
        
        # set channel range of skin detection 
        self.mask_lower_yrb = np.array([44, 131, 80])       # [54, 131, 110]
        self.mask_upper_yrb = np.array([163, 157, 155])     # [163, 157, 135]
        # create trackbar for skin calibration
        self.calib_switch = False

        # create background subtractor 
        self.fgbg = cv2.BackgroundSubtractorMOG2(history=120, varThreshold=50, bShadowDetection=True)

        # define dynamic ROI area
        self.ROIx, self.ROIy = 200, 200
        self.track_switch = False
        # record previous positions of the centroid of ROI
        self.preCX = None
        self.preCY = None

        # A queue to record last couple gesture command
        self.last_cmds = FixedQueue()
        
        # prepare some data for detecting single-finger gesture  
        self.fin1 = cv2.imread('./test_data/index1.jpg')
        self.fin2 = cv2.imread('./test_data/index2.jpg')
        self.fin3 = cv2.imread('./test_data/index3.jpg')

        # switch to turn on mouse input control
        self.cmd_switch = False
        
        # count loop (frame), for debugging
        self.n_frame = 0


# On-line Calibration for skin detection (bug, not stable)
    def skin_calib(self, raw_yrb):
        mask_skin = cv2.inRange(raw_yrb, self.mask_lower_yrb, self.mask_upper_yrb)
        cal_skin = cv2.bitwise_and(raw_yrb, raw_yrb, mask=mask_skin)
        cv2.imshow('YRB_calib', cal_skin)
        k = cv2.waitKey(5) & 0xFF
        if k == ord('s'):
            self.calib_switch = False
            cv2.destroyWindow('YRB_calib')

        ymin = cv2.getTrackbarPos('Ymin', 'YRB_calib')
        ymax = cv2.getTrackbarPos('Ymax', 'YRB_calib')
        rmin = cv2.getTrackbarPos('CRmin', 'YRB_calib')
        rmax = cv2.getTrackbarPos('CRmax', 'YRB_calib')
        bmin = cv2.getTrackbarPos('CBmin', 'YRB_calib')
        bmax = cv2.getTrackbarPos('CBmax', 'YRB_calib')
        self.mask_lower_yrb = np.array([ymin, rmin, bmin])
        self.mask_upper_yrb = np.array([ymax, rmax, bmax])


# Do skin detection with some filtering
    def skin_detect(self, raw_yrb, img_src):
        # use median blurring to remove signal noise in YCRCB domain
        raw_yrb = cv2.medianBlur(raw_yrb, 5)
        mask_skin = cv2.inRange(raw_yrb, self.mask_lower_yrb, self.mask_upper_yrb)

        # morphological transform to remove unwanted part
        kernel = np.ones((5, 5), np.uint8)
        #mask_skin = cv2.morphologyEx(mask_skin, cv2.MORPH_OPEN, kernel)
        mask_skin = cv2.dilate(mask_skin, kernel, iterations=2)

        res_skin = cv2.bitwise_and(img_src, img_src, mask=mask_skin)
        #res_skin_dn = cv2.fastNlMeansDenoisingColored(res_skin, None, 10, 10, 7,21)

        return res_skin


# Do background subtraction with some filtering
    def background_subtract(self, img_src):
        fgmask = self.fgbg.apply(cv2.GaussianBlur(img_src, (25, 25), 0))
        kernel = np.ones((5, 5), np.uint8)
        fgmask = cv2.dilate(fgmask, kernel, iterations=2)
        #fgmask = self.fgbg.apply(cv2.medianBlur(img_src, 11))
        org_fg = cv2.bitwise_and(img_src, img_src, mask=fgmask)
        return org_fg

# Update Position of ROI
    def update_ROI(self, img_src):
        # setting flexible ROI range
        Rxmin,Rymin,Rxmax,Rymax = (0,)*4
        if self.ROIx - 100 < 0:
            Rxmin = 0
        else:
            Rxmin = self.ROIx - 100
        
        if self.ROIx + 100 > img_src.shape[0]:
            Rxmax = img_src.shape[0]
        else:
            Rxmax = self.ROIx + 100
        
        if self.ROIy - 100 < 0:
            Rymin = 0
        else:
            Rymin = self.ROIy - 100
        
        if self.ROIy + 100 > img_src.shape[1]:
            Rymax = img_src.shape[1]
        else:
            Rymax = self.ROIy + 100
        
        return Rxmin, Rymin, Rxmax, Rymax


# Find contour and track hand inside ROI
    def find_contour(self, img_src, Rxmin, Rymin, Rxmax, Rymax):
        cv2.rectangle(img_src, (Rxmax, Rymax), (Rxmin, Rymin), (0, 255, 0), 0)
        crop_res = img_src[Rymin: Rymax, Rxmin:Rxmax]
        grey = cv2.cvtColor(crop_res, cv2.COLOR_BGR2GRAY)

        _, thresh1 = cv2.threshold(grey, 127, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

        cv2.imshow('Thresh', thresh1)
        contours, hierchy = cv2.findContours(thresh1.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

        # draw contour on threshold image
        if len(contours) > 0:
            cv2.drawContours(thresh1, contours, -1, (0, 255, 0), 3)
            
        return contours, crop_res


# Check ConvexHull  and Convexity Defects
    def get_defects(self, cnt, drawing):
        defects = None        
        hull = cv2.convexHull(cnt)
        cv2.drawContours(drawing, [cnt], 0, (0, 255, 0), 0)
        cv2.drawContours(drawing, [hull], 0, (0, 0, 255), 0)
        hull = cv2.convexHull(cnt, returnPoints=False)       # For finding defects
        if hull.size > 2:
            defects = cv2.convexityDefects(cnt, hull)        
        
        return defects


# Gesture Recognition
    def gesture_recognize(self, cnt, defects, count_defects, crop_res):
        # use angle between start, end, defect to recognize # of finger show up
        if type(defects) is not None and cv2.contourArea(cnt) >= 5000:
            for i in range(defects.shape[0]):
                s, e, f, d = defects[i, 0]
                start = tuple(cnt[s][0])
                end = tuple(cnt[e][0])
                far = tuple(cnt[f][0])
                a = math.sqrt((end[0] - start[0])**2 + (end[1] - start[1])**2)
                b = math.sqrt((far[0] - start[0])**2 + (far[1] - start[1])**2)
                c = math.sqrt((end[0] - far[0])**2 + (end[1] - far[1])**2)
                angle = math.acos((b**2 + c**2 - a**2)/(2*b*c)) * 180/math.pi
                if angle <= 90:
                    count_defects += 1
                    cv2.circle(crop_res, far, 5, [0, 0, 255], -1)
                cv2.line(crop_res, start, end, [0, 255, 0], 2)
                
        ## single fingertip check
        if count_defects == 0 and cv2.contourArea(cnt) >= 5000:
            count_defects = self.single_finger_check(cnt)
        
        # return the result of gesture recognition
        return count_defects


# Check if single-finger show up (OpenCV API using matchShape)
    def single_finger_check(self, cnt):
        # use single finger image to check current fame has single finger
        grey_fin1 = cv2.cvtColor(self.fin1, cv2.COLOR_BGR2GRAY)
        _, thresh_fin1 = cv2.threshold(grey_fin1, 127, 255, 0)
        contour_fin1, hierarchy = cv2.findContours(thresh_fin1.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
        cnt1 = contour_fin1[0]
        ret1 = cv2.matchShapes(cnt, cnt1, 1, 0)
        
        grey_fin2 = cv2.cvtColor(self.fin2, cv2.COLOR_BGR2GRAY)
        _, thresh_fin2 = cv2.threshold(grey_fin2, 127, 255, 0)
        contour_fin2, hierarchy = cv2.findContours(thresh_fin2.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
        cnt2 = contour_fin2[0]
        ret2 = cv2.matchShapes(cnt, cnt2, 1, 0)
        
        grey_fin3 = cv2.cvtColor(self.fin3, cv2.COLOR_BGR2GRAY)
        _, thresh_fin3 = cv2.threshold(grey_fin3, 127, 255, 0)
        contour_fin3, hierarchy = cv2.findContours(thresh_fin3.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
        cnt3 = contour_fin3[0]
        ret3 = cv2.matchShapes(cnt, cnt3, 1, 0)
        reta = (ret1 + ret2 + ret3)/3
        if reta <= 0.3:
            return 5        # set as one-finger module
        else:
            return 0        # not detect, still 0


# Use PyAutoGUI to control mouse event
    def input_control(self, count_defects, img_src):
        # update position difference with previous frame (for move mouse)
        d_x, d_y = 0, 0
        if self.preCX is not None:
            d_x = self.ROIx - self.preCX
            d_y = self.ROIy - self.preCY
        
        # checking current command, and filter out unstable hand gesture
        cur_cmd = 0
        if self.cmd_switch:
            if self.last_cmds.count(count_defects) >= self.last_cmds.n_maj:
                cur_cmd = count_defects
                #print 'major command is ', cur_cmd
            else:
                cur_cmd = 0     # self.last_cmds.major()
        else:
            cur_cmd = count_defects
        
        # send mouse input event depend on hand gesture
        if cur_cmd == 1:
            str1 = '2, move mouse dx,dy = ' + str(d_x*3) + ', ' + str(d_y*3)
            cv2.putText(img_src, str1, (50, 50), cv2.FONT_HERSHEY_TRIPLEX, 2, (0, 0, 255), 2)
            if self.cmd_switch:
                pyautogui.moveRel(d_x*3, d_y*3)
                self.last_cmds.push(count_defects)
                #pyautogui.mouseDown(button='left')
                #pyautogui.moveRel(d_x, d_y)
            #else:
            #    pyautogui.mouseUp(button='left')
        elif cur_cmd == 2:
            cv2.putText(img_src, '3 Left (rotate)', (50, 50), cv2.FONT_HERSHEY_TRIPLEX, 2, (0, 0, 255), 2)
            if self.cmd_switch:
                pyautogui.dragRel(d_x, d_y, button='left')
                self.last_cmds.push(count_defects)
                #pyautogui.scroll(d_y,pause=0.2) 
        elif cur_cmd == 3:
            cv2.putText(img_src, '4 middle (zoom)', (50, 50), cv2.FONT_HERSHEY_TRIPLEX, 2, (0, 0, 255), 2)
            if self.cmd_switch:
                pyautogui.dragRel(d_x, d_y, button='middle')
                self.last_cmds.push(count_defects)
        elif cur_cmd == 4:
            cv2.putText(img_src, '5 right (pan)', (50, 50), cv2.FONT_HERSHEY_TRIPLEX, 2, (0, 0, 255), 2)
            if self.cmd_switch:
                pyautogui.dragRel(d_x, d_y, button='right')
                self.last_cmds.push(count_defects)
        elif cur_cmd == 5:
            cv2.putText(img_src, '1 fingertip show up', (50, 50), cv2.FONT_HERSHEY_TRIPLEX, 2, (0, 0, 255), 2)
            if self.cmd_switch:
                self.last_cmds.push(count_defects)
        else:
            cv2.putText(img_src, 'No finger detect!', (50, 50), cv2.FONT_HERSHEY_TRIPLEX, 2, (0, 0, 255), 2)
            if self.cmd_switch:
                self.last_cmds.push(count_defects)  # no finger detect or wrong gesture


# testing pyautogui
    def test_auto_gui(self):
        if self.cmd_switch:
            # Drag mouse to control some object on screen (such as google map at webpage)
            distance = 100.
            while distance > 0:
                pyautogui.dragRel(distance, 0, duration=2, button='left')    # move right
                distance -= 25
                pyautogui.dragRel(0, distance, duration=2, button='left')    # move down
                distance -= 25
                pyautogui.dragRel(-distance, 0, duration=2, button='left')    # move right
                distance -= 25
                pyautogui.dragRel(0, -distance, duration=2, button='left')    # move down
                distance -= 25

            # scroll mouse wheel (zoom in and zoom out google map)
            pyautogui.scroll(10, pause=1.)
            pyautogui.scroll(-10, pause=1)

            pyautogui.scroll(10, pause=1.)
            pyautogui.scroll(-10, pause=1)

            # message box
            pyautogui.alert(text='pyautogui testing over, click ok to end', title='Alert', button='OK')
            self.cmd_switch = not self.cmd_switch   # turn off

# main function of the project (run all processes)
    def run(self):
        while self.cam.isOpened():
            if self.n_frame == 0:
                ini_time = time.time()
            ret, self.frame = self.cam.read()
            org_vis = self.frame.copy()
            #org_vis = cv2.fastNlMeansDenoisingColored(self.frame, None, 10,10,7,21) # try to denoise but time comsuming

            ### Skin detect filter
            yrb = cv2.cvtColor(self.frame, cv2.COLOR_BGR2YCR_CB)
            res_skin = self.skin_detect(yrb, org_vis)

            ## check if want to do skin calibration
            if self.calib_switch:
                self.skin_calib(yrb)
            
            ### Background Subtraction
            org_fg = self.background_subtract(org_vis)

            ### Find Contours and track hand inside ROI
            Rxmin, Rymin, Rxmax, Rymax = self.update_ROI(org_fg)
            contours, crop_res = self.find_contour(org_fg, Rxmin, Rymin, Rxmax, Rymax)

            ### Get Convexity Defects if Contour in ROI is bigger enough 
            drawing = np.zeros(crop_res.shape, np.uint8)
            max_area = -1
            ci = 0
            if len(contours) > 0:
                for i in range(len(contours)):
                    cnt = contours[i]
                    area = cv2.contourArea(cnt)
                    if area > max_area:
                        max_area = area
                        ci = i
                cnt = contours[ci]

                # use minimum rectangle to crop contour for faster gesture checking
                x, y, w, h = cv2.boundingRect(cnt)
                cv2.rectangle(crop_res, (x, y), (x+w, y+h), (0, 0, 255), 0)

                # check if start to track hand
                if self.track_switch:
                    M = cv2.moments(cnt)
                    if M['m00'] != 0:
                        self.ROIx = int(M['m10']/M['m00']) + Rxmin
                        self.ROIy = int(M['m01']/M['m00']) + Rymin - 30
                    else:
                        self.ROIx = 200
                        self.ROIy = 200

                # debug draw a  circle at center
                M = cv2.moments(cnt)
                if M['m00'] != 0:
                    cx = int(M['m10']/M['m00'])
                    cy = int(M['m01']/M['m00'])
                    cv2.circle(org_fg, (cx+Rxmin, cy+Rymin), 10, [0, 255, 255], -1)
                
                ### Check ConvexHull  and Convexity Defects
                defects = self.get_defects(cnt, drawing)

                ### Gesture Recognition
                count_defects = 0
                count_defects = self.gesture_recognize(cnt, defects, count_defects, crop_res)

                ### Input Control (Mouse Event)
                self.input_control(count_defects, org_fg)

                # update center position of ROI for next frame
                self.preCX = self.ROIx
                self.preCY = self.ROIy

            ### Display Image
            #cv2.imshow('original_view', org_vis)
            #cv2.imshow('YCR_CB', yrb)
            #cv2.imshow('YRB_skin', res_skin)
            #cv2.imshow('fgmask', fgmask)
            cv2.imshow('gesture_hci', org_fg)         # final result shows Here

            all_img = np.hstack((drawing, crop_res))
            cv2.imshow('Contours', all_img)

            #self.test_auto_gui()

            ch = cv2.waitKey(5) & 0xFF
            if ch == 27:
                break
            elif ch == ord('c'):
                self.cmd_switch = not self.cmd_switch
            elif ch == ord('s'):
                self.calib_switch = not self.calib_switch
            elif ch == ord('t'):
                self.track_switch = not self.track_switch

            if self.n_frame == 3:
                cur_time = time.time()
                #print 'time for one loop:',(cur_time - ini_time)
            self.n_frame = (self.n_frame + 1) % 4

        cv2.destroyAllWindows()


if __name__ == '__main__':
    # main function start here
    try:
        video_src = sys.argv[1]
    except:
        video_src = 0
    print(__doc__)
    App(0).run()
# Out:
# Hand gesture recognition
# ==========================
# This is main function for the project.
# Source Code:
# https://github.com/RobinCPC/CE264-Computer_Vision
# Usage:
# ------
#     gesture_hci.py [<video source>] (default: 0)
# Keys:
# -----
#     ESC     - exit
#     c       - toggle mouse control (default: False)
#     t       - toggle hand tracking (default: False)
#     s       - toggle skin calibration (need debug)
